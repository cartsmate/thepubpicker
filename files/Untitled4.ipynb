# %%
import os
import pandas as pd
import numpy as np
directory_path = os.getcwd()
# df_det = pd.read_csv(directory_path + '/details.csv')
df_rev = pd.read_csv(directory_path + '/reviews.csv')
df_copy = pd.read_csv(directory_path + '/reviews_copy.csv')
# df.shape[0]

# df['pub_identity'].nunique()

# # df = pd.read_csv("dup.csv")
# ids = df["pub_identity"]
# df[ids.isin(ids[ids.duplicated()])].sort_values("pub_identity")

# df_joined = df_det.merge(df, on='pub_identity', how='left', indicator=True)
# df_joined


# df_missing = df_det[~df_det['pub_identity'].isin(df['pub_identity'])]
# df_missing['pub_identity'].tolist()

# df_missing2 = df[~df['pub_identity'].isin(df_det['pub_identity'])]
# df_missing2

# # # for index, row in df.iterrows():
# # #     print(row['c1'], row['c2'])
    
# # # df_miss_id = df_missing2['pub_identity']
# # # df_miss_id.shape[0]
# # # df_missing
# # df_new = df[~df['pub_identity'].isin(df_missing2['pub_identity'])]
# # df_new.shape[0]

# df['cocktail'] =0
# df.head(2)
# df.columns.tolist()
# df2 = df[['review_identity',
#  'review_deletion',
#  'pub_identity',
#  'beer',
#  'brunch',
#  'cocktail',
#  'dart',
#  'entertain',
#  'favourite',
#  'garden',
#  'history',
#  'late',
#  'music',
#  'pool',
#  'quiz',
#  'roast',
#  'sport',
#  'nofeature']]
# df2.head(2)
# df_rev.head(2)
# df_rev['beer'] = '0'
# df_rev['cocktail'] = '0'
# df_rev['outdoor'] = '0'
# df_rev['restaurant'] = '0'
# df_rev['wine'] = '0'
# df_rev.columns.tolist()

# df2 = df_rev[['review_identity',
#  'review_deletion',
#  'pub_identity',
#  'brunch',
#  'dart',
#  'entertain',
#  'favourite',
#  'garden',
#  'history',
#  'late',
#  'music',
#  'pool',
#  'quiz',
#  'roast',
#  'sport',
#  'beer',
#  'cocktail',
#  'outdoor',
#  'restaurant',
#  'wine',
#  'nofeature']]
# df2.head(2)

# %%
import uuid
print(str(uuid.uuid4()))
# Out:
# 463d714c-be3b-4167-a9b7-fe293d9c7e69

# %%
import os
import pandas as pd
import numpy as np
directory_path = os.getcwd()
# df_rev = pd.read_csv(directory_path + '/reviews.csv', dtype={'garden': str, 'roast': str})
# df_dtl = pd.read_csv(directory_path + '/detail.csv')
df_rev = pd.read_csv(directory_path + '/review.csv')
# df_st = pd.read_csv(directory_path + '/station.csv')
df_evnt = pd.read_csv(directory_path + '/event.csv')
df_dtl_rev = pd.merge(df_dtl, df_rev, on='pub_identity', how='left')
df_dr_st = pd.merge(df_dtl_rev, df_st, on='station_identity', how='left')
df_join = pd.merge(df_dr_st, df_evnt, on='pub_identity', how='left')
df_join = df_join.loc[(df_join['music'] == '1')|(df_join['music'] == 1)]
# & (df['column_name'] <= B)]
df_join[['detail_name','event_type']]
# df_filtered.shape[0]
filtered_df = df_join[df_join['event_identity'].isna()]
filtered_df[['pub_identity','detail_name','address', 'station_name','event_type']].sort_values('station_name')
# Out:
#                               pub_identity                     detail_name  \
# 774   0a1f8e69-4020-4dad-8a4a-a3925e7d03ce                   Hope & Anchor
# 1526                 16 Carlisle St, London W1D 3BT, UK
# 1360          Archway 435, Avenue Rd, London E7 0JN, UK
#
#                 station_name event_type
# 774   Highbury and Islington        NaN
# 387                 Highgate        NaN
# 1941                Kingston        NaN
# 515             Latimer Road        NaN
# 1375             Leytonstone        NaN
# 1661           London Fields        NaN
# 364              Manor House        NaN
# 37                Old Street        NaN
# 1796              Old Street        NaN
# 1794              Old Street        NaN
# 482            Palmers Green        NaN
# 1980       Piccadilly Circus        NaN
# 43         Piccadilly Circus        NaN
# 556                  Pimlico        NaN
# 1145     Queens Road Peckham        NaN
# 541   Shoreditch High Street        NaN
# 1780  Shoreditch High Street        NaN
# 1783  Shoreditch High Street        NaN
# 1784  Shoreditch High Street        NaN
# 247   Shoreditch High Street        NaN
# 1370             Snaresbrook        NaN
# 1526    Tottenham Court Road        NaN
# 1360           Wanstead Park        NaN

# %%
import os
import pandas as pd
import numpy as np
directory_path = os.getcwd()
df_rev = pd.read_csv(directory_path + '/review.csv')
# df_rev2 = df_rev.loc[df_rev['review_identity'].isna()]
df_rev['review_identity']=np.where(df_rev['review_identity'].isna(),str(uuid.uuid4()),df_rev['review_identity'])

# df_evnt = pd.read_csv(directory_path + '/event.csv')
# df_evnt2 = df_evnt.loc[(df_evnt['event_type'] == 'comedy')]
# df_rev_evnt = pd.merge(df_rev, df_evnt2, on='pub_identity', how='right')
# df = df_rev_evnt[['pub_identity']]
# df_rev_evnt2 = df_rev_evnt.loc[(df_rev_evnt['entertain'] == '1')|(df_rev_evnt['entertain'] == 1)]

# df_join[['detail_name','event_type']]
# filtered_df = df_join[df_join['event_identity'].isna()]
# filtered_df[['pub_identity','detail_name','address', 'station_name','event_type']].sort_values('station_name')

# df = df_rev_evnt2[['pub_identity']]

              # ,'entertain','comedy','karaoke','event_type','event_detail']]

# %%
df_rev.to_csv(directory_path + '/review.csv', index=False, sep=',', encoding='utf-8')

# %%
# df_rev.to_csv(directory_path + '/review.csv', index=False, sep=',', encoding='utf-8')
# df_evnt.loc[df_evnt['event_detail'] == 'Karaoke', 'event_type'] = 'karaoke'
import numpy as np
df_rev_evnt = pd.merge(df_rev, df_evnt, on='pub_identity', how='left')
df_rev_evnt.shape[0]
# df_rev['karaoke']=np.where(df_rev_evnt['event_type'] == 'karaoke','1','0')
# df_rev.shape[0]
# Out:
# 2283

# %%
import os
import pandas as pd
import numpy as np
directory_path = os.getcwd()
df_eve = pd.read_csv(directory_path + '/events.csv')
# df_eve.shape[0]
# Total: 532
# Quiz: 153
# Live music: 114
# Closed: 121
# other: 144
# df_filtered = df_eve.loc[(df_eve['event_type'] == 'Closed')] 
df_filtered = df_eve[(df_eve['event_type'] != 'Quiz') & (df_eve['event_type'] != 'Live music' ) & (df_eve['event_type'] != 'Closed' )]
df_filtered
# Out:
#                            event_identity  \
# 27   9a91c6c1-3783-4278-a5c6-ec90437cb315
# 28   3b0efa92-4713-4bab-9b25-5837c2b7460f
# 29   b8917737-098c-4d26-bfee-88fcf9b9d17f
# 41   deba1eb1-b6f7-4829-847d-5fa516abd56e
# 42   36957e16-4718-49f4-9df8-9745f2b80aae
# ..                                    ...
# 502  3f6e8c3b-31b4-4451-be0d-21a060fe2a98
# 512  4b6def54-9c08-4a2e-be99-b5e5ec76f5f1
# 514  94ccdd8b-9468-4557-8eb3-e272f6251e9f
# 515  690aacbd-51d4-4270-8e17-5b15f74a00e2
# 517  2ec7d47c-5c21-471e-9021-27e7f4c38135
#
#                              pub_identity  event_day  \
# 27   04738700-75a2-4d5c-864d-de41c81995db     sunday
# 28   04ea139a-05b9-42ee-8bd0-3f3271c750e1     monday
# 29   05493a89-5d8f-407c-b5ca-d269f6d5af55   saturday
# 41   0a0b64ce-badb-49b7-b4e6-2a725d564598    tuesday
# 42   0a0b64ce-badb-49b7-b4e6-2a725d564598     friday
# ..                                    ...        ...
# 502  f74c12e3-3d4d-43c8-89a7-57431146438d     sunday
# 512  fb633682-9d29-47d1-81cd-a1848becebb0   thursday
# 514  fbfe14ab-a48b-424f-b09d-6c1478f0edcb  wednesday
# 515  fbfe14ab-a48b-424f-b09d-6c1478f0edcb   thursday
# 517  ff1be3fe-9942-441e-a9e3-f329d0b65eb2     monday
#
#                             event_time                         event_type
# 27                                 NaN                          live jazz
# 28                               Bingo                              Bingo
# 29                                Noon                             Brunch
# 41                         board games                        board games
# 42                                 DJs                                DJs
# ..                                 ...                                ...
# 502                        Sing-a-long                        Sing-a-long
# 512  Live jazz music last of the month  Live jazz music last of the month
# 514                            Karaoke                            Karaoke
# 515                         Race night                         Race night
# 517                           Quiz 8pm                           Quiz 8pm
#
# [144 rows x 5 columns]

# %%
import os
import csv
import pandas as pd
import numpy as np
directory_path = os.getcwd()
full_file = []
days_of_the_week = ['monday','tuesday','wednesday','thursday','friday','saturday','sunday']
df_events = pd.read_csv(directory_path + '/events.csv')


with open(directory_path + '/details.csv') as csv_file:
    next(csv_file)
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        new_line = []
        # print(row[0])
        df_filtered = df_events.loc[(df_events['pub_identity'] == row[0])]
        # print(df_filtered)
        new_line.append(row[0])
        for day in days_of_the_week:
            # print(day)
            try:
                df_day = df_filtered.loc[(df_filtered['event_day'] == day)]
                var_event = df_day['event_identity'].values[0]
            except IndexError:
                var_event = '0'
            
            # print(df_day['event_identity'].values[0])
            new_line.append(var_event)
        full_file.append(new_line)
        # break
# print(full_file)
# df_evnt3.to_csv(directory_path + '/events.csv', index=False, sep=',', encoding='utf-8')

with open('diary.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(full_file)

# %%
import os
import pandas as pd
import numpy as np
directory_path = os.getcwd()
df_evnt = pd.read_csv(directory_path + '/events.csv')
all = df_evnt.shape[0]

df_evnt2 = df_evnt.loc[(df_evnt['event_time'] == 'TBC') & (df_evnt['event_type'] == 'TBC')]
some = df_evnt2.shape[0]
# df_evnt2.shape[0]
print(all, some)

df_evnt3 = df_evnt.drop(df_evnt[df_evnt['event_type'] == 'TBC'].index)
df_evnt3.shape[0]
# Out:
# 3729 2746
# 983

# %%
import os
import pandas as pd
import numpy as np
directory_path = os.getcwd()
df_full = pd.read_csv(directory_path + '/events_full.csv')
df_full.shape[0]
# Out:
# 8729

# %%
df2.to_csv(directory_path + '/reviews.csv', index=False, sep=',', encoding='utf-8')

# %%
df_copy = pd.read_csv(directory_path + '/reviews_copy.csv')
df_copy.head(2)
rslt_df = df_copy[df_copy[name] == 1]
rslt_df.shape[0]
# Out:
# 343

# %%
df_rev.head(2)
rslt_df_rev = df_rev[df_rev[name] == 1]
rslt_df_rev.shape[0]
# Out:
# 343

# %%
df_backup = pd.read_csv(directory_path + '/backups/reviews.csv')
df_backup.head(2)
rslt_df_bkp = df_backup[df_backup[name] == 1]
rslt_df_bkp.shape[0]
# Out:
# 7

# %%
import uuid
uuid.uuid4()
# Out:
# UUID('1961d8ab-8494-4646-8c77-b6799fc20915')

# %%
t1 = datetime.datetime.now()
print(t1)
# Out:
# 2023-12-26 22:31:31.875725

# %%
import datetime
import time

t1 = datetime.datetime.now()
# t1_day = t1.weekday()
# print(t1_day)
# print(str(t1_day) + ' : ' + t1)
time.sleep(2.5)

t2 = datetime.datetime.now()
# t2_day = t2.weekday()
# print(t2_day)
# print(str(t2_day) + ' : ' + t2)

# _1_day = datetime.timedelta(days=1)
# t3 = datetime.datetime.now() - t1
if ((t2 - t1) > datetime.timedelta(days=1) or t1.weekday() != t2.weekday()):
    print("next day")
else:
    print("same day")


# print('Timestamp: {:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now()))
# print('Timestamp: {:%Y-%b-%d %H:%M:%S}'.format(datetime.datetime.now()))
# print('Date now: %s' % datetime.datetime.now())
# print('Date today: %s' % datetime.date.today())

# today = datetime.date.today()
# print("Today's date is {:%b, %d %Y}".format(today))
# Out:
# same day

# %%
import os
import pandas as pd
import requests
base_photo_url = 'https://maps.googleapis.com/maps/api/place/photo?maxwidth=300&photo_reference='
base_url = 'https://maps.googleapis.com/maps/api/place/details/json?'
key = 'AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20'
fields = 'name,photos'
https://maps.googleapis.com/maps/api/place/photo?maxwidth=300
&photo_reference=

https://maps.googleapis.com/maps/api/place/photo?maxwidth=300&photo_reference=AWU5eFjFsO_BtNvCMQvj-Vg2CDzuns6TZGBnqUKNbWK4pcpRYmqscahEK4sbxuF3EDmJi1FTYAss-Ag561FXRyKmniK-F9I86-YWxbpy_0PEcOGxYv-kpLEDxpgoZWvsCWZKbejM7j1vZygbAEY_5_99PDgtTP0081mbNtWnu4FFiBs4-clI&key=AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20


AWU5eFhElLJ2P1H-eKHJbLNayNjCubz9FmbrcmN2MMfbRsEdSKYyCGX_NaiCYp_tGUnY6pMHPpLDjRf8ofGV2tqg0Xk9xnbhxvrG-s43jLXp-2ngJRA9J5oWe4U1_i2lxy-rUrZrStwQWtrr9dJv3spX6TA8dfCYNrejbGNnNJ_1ljsunVbk
&key=AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20
directory_path = os.getcwd()
df_details = pd.read_csv(directory_path + '/details.csv')
df_photos = pd.read_csv(directory_path + '/photos.csv')
for index, row in df_details.iterrows():
    name = row['detail_name']
    pub_id = row['pub_identity']
    full_url = base_url + "place_id=" + place_id + "&key=" + key + "&fields=" + fields
    # full_photo_url = base_photo_url + photo_id + "&key=" + key 
    # + "&fields=" + fields

    response = requests.get(full_url)
    photo_ids = response.json()['result']['photos']
    total_photo_list = []
    for x in photo_ids:
        new_list = [x['photo_reference'], 'false', pub_id]
        # print(new_list)
        total_photo_list.append(new_list)
        # print(new_photo_list)
    # print(total_photo_list)
    df_new_photo = pd.DataFrame(total_photo_list, columns=['photo_identity', 'photo_deletion', 'pub_identity'])
    # print(df_new_photo)
    df_photos = pd.concat([df_photos, df_new_photo], ignore_index=True)
    df_photos.to_csv(directory_path + '/photos_api.csv', index=False, sep=',', encoding='utf-8')

# %%
base_url = 'https://maps.googleapis.com/maps/api/place/details/json?'
key = 'AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20'
fields = 'name,photos'
place_id = 'ChIJKZfgUMoEdkgRjRIYygsCkSY'
full_url = base_url + "place_id=" + place_id + "&key=" + key + "&fields=" + fields
full_url
# response = requests.get(full_url)
# Out:
# 'https://maps.googleapis.com/maps/api/place/details/json?place_id=ChIJKZfgUMoEdkgRjRIYygsCkSY&key=AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20&fields=name,photos'

# %%
key = 'AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20'
base_url_photo = 'https://maps.googleapis.com/maps/api/place/photo?maxwidth=300&photo_reference='
photo_id = 'AWU5eFiCA83ZAirE1G3P6i2ZqiZJzM1qYEMy71xNRqEJIwy6tGnnHSBP1x_SB802f148a9ADpjZWdKUPU4HSK0HH4N4PPd6fmcaKfT2vBKiBuY7QYzKUS__Tgydea4pFdmaO6dNTLvtZrcxY2vha3_GTWISSovCC6SFPcbS960-ZNgINRgmv'
photo_id2 = 'AWU5eFhESHVBggKCxK5FWh6zm3GSFTpbVR69fne2gMa203UClOiOsyqwgyw25FaqEvFF7LN1OpD9L3Z9gFmw8VRF0VEZFkQ3DURWfx1RIWE_o7_XrGGS-SkHqQ8Su0xVcaJeUBU-tA_qIG0AC_CW8FrECBxdoyxPHV2UvIIZvRPG3Czv_TvM'
photo_id3 = 'AWU5eFhkLXXNuJFEyHS7f0SVMOVfzxXfzCHn7hFhG0Bfi82GlAzEbQKT_a9UaeVUSLYdK3yKVo0HCQ-RYMmZtYd-Wg6JfQWhbDhbn_PjyUOZ6XScig9gzCtAZb8UJ-35ddqwCIEK6qy7MJnmh5IcYcJFZoyVGPAPn8tCOFaEi_9jhFscbJLH'
full_url = base_url_photo + photo_id3 + "&key=" + key
full_url
# Out:
# 'https://maps.googleapis.com/maps/api/place/photo?maxwidth=300&photo_reference=AWU5eFhkLXXNuJFEyHS7f0SVMOVfzxXfzCHn7hFhG0Bfi82GlAzEbQKT_a9UaeVUSLYdK3yKVo0HCQ-RYMmZtYd-Wg6JfQWhbDhbn_PjyUOZ6XScig9gzCtAZb8UJ-35ddqwCIEK6qy7MJnmh5IcYcJFZoyVGPAPn8tCOFaEi_9jhFscbJLH&key=AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20'

# %%
import os
import requests
import pandas as pd
directory_path = os.getcwd()

# df[['extra','place','url','website']]

base_url = 'https://maps.googleapis.com/maps/api/place/details/json?'
key = 'AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20'
fields = 'name,url,website,editorial_summary'

df_detail = pd.read_csv(directory_path + '/detail.csv')

for index, row in df_detail.iterrows():
    print('index: ' + str(index))
    name = row['detail_name']
    pub_id = row['pub_identity']
    website = row['website']
    url = row['url']
    extra = row['extra']
    place_id = row['place']
    full_url = base_url + "place_id=" + place_id + "&key=" + key + "&fields=" + fields

    response = requests.get(full_url)
    
    try:
        new_name = response.json()['result']['name']
        if (name != new_name):
            print('name :-')
            print(name + ' | ' + new_name + ' : MISMATCHES')
            df_detail.loc[df_detail['pub_identity'] == pub_id, 'detail_name'] = new_name
            
        try:
            new_website = response.json()['result']['website']
            if (website != new_website):
                print('website :-')
                print(website + ' | ' + new_website + ' : MISMATCHES')
                df_detail.loc[df_detail['pub_identity'] == pub_id, 'website'] = new_website
        except Exception:
            pass
            # print('no website for: ' + new_name)
            # print('current website saved: ' + website)

        try:
            new_url = response.json()['result']['url']
            if (url != new_url):
                print('url :-')
                print(url + ' | ' + new_url + ' : MISMATCHES')
                df_detail.loc[df_detail['pub_identity'] == pub_id, 'url'] = new_url
        except Exception:
            pass
            # print('no url for: ' + new_name)
            # print('current url saved: ' + url)

        try:    
            new_extra = response.json()['result']['editorial_summary']['overview']
            if (extra != new_extra):
                print('extra :-')
                print(extra + ' | ' + new_extra + ' : MISMATCHES')
                df_detail.loc[df_detail['pub_identity'] == pub_id, 'extra'] = new_extra
        except Exception:
            pass
            # print('no summary for: ' + new_name)
            # print('current summary saved: ' + extra)

    except:
        print('Error')
        print('csv name: ' + name)
        print('csv pub id: ' + pub_id)
        print('csv place id: ' + place_id)
        print('response: ')
        print(response.json())
df_detail.to_csv(directory_path + '/detail.csv', index=False, sep=',', encoding='utf-8')

    # break
    
# place_id = 'ChIJy2QpfVUDdkgR_ZjHMTwf28A'
# key = 'AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20'
# fields = 'name,url,website,photos,editorial_summary'
# full_url = base_url + "place_id=" + place_id + "&key=" + key + "&fields=" + fields
# # response = requests.get("https://maps.googleapis.com/maps/api/place/details/json?place_id=ChIJy2QpfVUDdkgR_ZjHMTwf28A&key=AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20")
# response = requests.get(full_url)
# # print(response.json())
# response.json()['result']['name']
# response.json()['result']['url']
# response.json()['result']['website']
# response.json()['result']['editorial_summary']['overview']
# # print(len(response.json()['result']['photos']))

# fruits = response.json()['result']['photos']
# for x in fruits:
#   print(x['photo_reference'])
# Out:
# index: 0
# index: 1
# index: 2
# %%
import os
import pandas as pd
directory_path = os.getcwd()
df = pd.read_csv(directory_path + '/detail.csv')
df[['extra','place','url','website']]
# Out:
#                                                   extra  \
# 0                                  Women made wine shop
# 1     Pub with a history stretching back to the 17th...
# 2     Rebuilt after being bombed during the Blitz, w...
# 3     Gastropub for Modern British fare and local sp...
# 4     Pub in former coal cellar for the Savoy Hotel,...
# ...                                                 ...
# 1350  Relaxed tavern offering a selection of beers &...
# 1351  Pub with chandeliers and patterned wallpaper, ...
# 1352
# 1353  Visitors sing karaoke & drink cocktails at thi...
# 1354  Pub with autographed rock star hall of fame pi...
#
#                             place  \
# 0     ChIJta8CEZoddkgRzUPFFO6tYHc
# 1     ChIJy2QpfVUDdkgR_ZjHMTwf28A
# 2     ChIJtVNpD8sEdkgRW_kxR_77yN4
# 3     ChIJnx8u7bQEdkgRGm5XKuA0SBQ
# 4     ChIJPyb_JskEdkgRDw4ffzUc8cQ
# ...                           ...
# 1350  ChIJ79XUyTsFdkgRj57LTskQHAo
# 1351  ChIJoaxnTn8DdkgRmUPgKypV5uA
# 1352  ChIJX76OWXgbdkgRE3rwNa-Yokk
# 1353  ChIJO37rxdQEdkgR-6IuXr0d0Uo
# 1354  ChIJd7_CwuMadkgR1iI2gEAlQHs
#
#                                                     url  \
# 0      https://maps.google.com/?cid=8602066526339941325
# 1     https://maps.google.com/?cid=13896735418575460605
# 2     https://maps.google.com/?cid=16053357941296855387
# 3      https://maps.google.com/?cid=1461476216469417498
# 4     https://maps.google.com/?cid=14191154916912729615
# ...                                                 ...
# 1350    https://maps.google.com/?cid=728475696523615887
# 1351  https://maps.google.com/?cid=16205733948752413593
# 1352   https://maps.google.com/?cid=5305971189287516691
# 1353   https://maps.google.com/?cid=5391122928105333499
# 1354   https://maps.google.com/?cid=8881139424133784278
#
#                                                 website
# 0                         https://www.wheresfinley.com/
# 1     https://www.nicholsonspubs.co.uk/restaurants/l...
# 2                        https://www.themarquess.co.uk/
# 3                    https://www.georgeinthestrand.com/
# 4     https://www.nicholsonspubs.co.uk/restaurants/l...
# ...                                                 ...
# 1350                                                NaN
# 1351               https://www.thecamberwellarms.co.uk/
# 1352                                                NaN
# 1353                        https://www.luckyvoice.com/
# 1354                    http://www.thehawleyarms.co.uk/
#
# [1355 rows x 4 columns]

# %%
    # UPDATE DF   
    for detail in list(Detail().__dict__.keys()):
            print(detail)
            print(detail + ' : ' + request.form[detail])
            df_details.loc[df_details['pub_identity'] == pub_id, detail] = request.form[detail]

# %%
    # ADD
    def add_detail_df(self, df_details, df_new):
        print('ADD new detail')
        df_appended = pd.concat([df_details, df_new], ignore_index=True)
        # df_full = pd.merge(df_details, df_new, on='pub_identity')
        return df_appended

# %%
    # UPDATE CSV
    def update_detail_csv(self, df_updated_details):
        print('updating detail csv')
        print(df_updated_details)
        df_updated_details.to_csv(directory_path + '/files/details.csv', index=False, sep=',', encoding='utf-8')
        print('csv updated')
        return df_updated_details
