# %%
import os
import pandas as pd
import numpy as np
directory_path = os.getcwd()
# df_det = pd.read_csv(directory_path + '/details.csv')
df_rev = pd.read_csv(directory_path + '/reviews.csv')
df_copy = pd.read_csv(directory_path + '/reviews_copy.csv')
# df.shape[0]

# df['pub_identity'].nunique()

# # df = pd.read_csv("dup.csv")
# ids = df["pub_identity"]
# df[ids.isin(ids[ids.duplicated()])].sort_values("pub_identity")

# df_joined = df_det.merge(df, on='pub_identity', how='left', indicator=True)
# df_joined


# df_missing = df_det[~df_det['pub_identity'].isin(df['pub_identity'])]
# df_missing['pub_identity'].tolist()

# df_missing2 = df[~df['pub_identity'].isin(df_det['pub_identity'])]
# df_missing2

# # # for index, row in df.iterrows():
# # #     print(row['c1'], row['c2'])
    
# # # df_miss_id = df_missing2['pub_identity']
# # # df_miss_id.shape[0]
# # # df_missing
# # df_new = df[~df['pub_identity'].isin(df_missing2['pub_identity'])]
# # df_new.shape[0]

# df['cocktail'] =0
# df.head(2)
# df.columns.tolist()
# df2 = df[['review_identity',
#  'review_deletion',
#  'pub_identity',
#  'beer',
#  'brunch',
#  'cocktail',
#  'dart',
#  'entertain',
#  'favourite',
#  'garden',
#  'history',
#  'late',
#  'music',
#  'pool',
#  'quiz',
#  'roast',
#  'sport',
#  'nofeature']]
# df2.head(2)
# df_rev.head(2)
# df_rev['beer'] = '0'
# df_rev['cocktail'] = '0'
# df_rev['outdoor'] = '0'
# df_rev['restaurant'] = '0'
# df_rev['wine'] = '0'
# df_rev.columns.tolist()

# df2 = df_rev[['review_identity',
#  'review_deletion',
#  'pub_identity',
#  'brunch',
#  'dart',
#  'entertain',
#  'favourite',
#  'garden',
#  'history',
#  'late',
#  'music',
#  'pool',
#  'quiz',
#  'roast',
#  'sport',
#  'beer',
#  'cocktail',
#  'outdoor',
#  'restaurant',
#  'wine',
#  'nofeature']]
# df2.head(2)

# %%
import uuid
print(str(uuid.uuid4()))
# Out:
# 463d714c-be3b-4167-a9b7-fe293d9c7e69

# %%
import os
import pandas as pd
import numpy as np
directory_path = os.getcwd()
# df_rev = pd.read_csv(directory_path + '/reviews.csv', dtype={'garden': str, 'roast': str})
# df_dtl = pd.read_csv(directory_path + '/detail.csv')
df_rev = pd.read_csv(directory_path + '/review.csv')
# df_st = pd.read_csv(directory_path + '/station.csv')
df_evnt = pd.read_csv(directory_path + '/event.csv')
df_dtl_rev = pd.merge(df_dtl, df_rev, on='pub_identity', how='left')
df_dr_st = pd.merge(df_dtl_rev, df_st, on='station_identity', how='left')
df_join = pd.merge(df_dr_st, df_evnt, on='pub_identity', how='left')
df_join = df_join.loc[(df_join['music'] == '1')|(df_join['music'] == 1)]
# & (df['column_name'] <= B)]
df_join[['detail_name','event_type']]
# df_filtered.shape[0]
filtered_df = df_join[df_join['event_identity'].isna()]
filtered_df[['pub_identity','detail_name','address', 'station_name','event_type']].sort_values('station_name')
# Out:
#                               pub_identity                     detail_name  \
# 774   0a1f8e69-4020-4dad-8a4a-a3925e7d03ce                   Hope & Anchor
# 387   cdfb2c2e-c05d-4891-9228-1e918c4ae0bc                 The Duke's Head
# 1941  24d297ea-6a37-4901-8324-5cb72605c770  The Fighting Cocks Bar & Venue
# 515   57da201e-7e6e-4fe2-b63c-3f43e3b4a66f                   Pig & Whistle
# 1375  102f5a13-bf8f-4d1d-9bcb-f11636f89aff           O'Neill's Leytonstone
# 1661  a34c0a55-6349-4ea9-9921-f0fba7c448b3                         Helgi's
# 364   1d738594-fab9-441a-ae75-2283218418d7                    The Finsbury
# 37    c7223326-661e-49ed-a0b2-da5bd4758508                        Nightjar
# 1796  6d0cf736-4720-4297-a4a8-ef7d91d5869e                   Gigi’s Hoxton
# 1794  3720c7c3-02f8-476c-8939-e1bbe2e72460                  Colours Hoxton
# 482   0f579ca8-06f4-427a-ab4d-ae685bc3a473                  The Dog & Duck
# 1980  a7bf6e94-b251-45f2-9175-93ed9122758a            Waxy's Little Sister
# 43    32a17618-9e23-450c-b921-a6bab0dfdd6f       Caffe Concerto Piccadilly
# 556   7b15a256-3742-43ad-94d9-b41f98266050               The Grosvenor pub
# 1145  1342830d-e087-49e6-8266-71ea278355b2               Prince of Peckham
# 541   eafd0eca-152d-4c97-a0d4-d3f68512420d               The Blues Kitchen
# 1780  db5b1a1d-a948-49d4-a75e-3680b9407846                  Strongroom Bar
# 1783  a3736fe9-92a4-4be3-af56-ce3ce6ef3eff                       Blues Bar
# 1784  0003ed1f-d8d6-4b77-afb0-847adc50937f              Old Street Records
# 247   c2d548eb-fa0d-4685-ad65-298a326e7095                 Queen of Hoxton
# 1370  4e1dbfe7-bc7a-4083-9304-1be5a4012604               The Duke Wanstead
# 1526  017b1ca6-ccb1-42d4-9c5e-1ea6c08064d6              The Piano Bar Soho
# 1360  3dbfd486-3e8f-4bc6-bb7a-bfa596c9a595               The Ciderhouse E7
#
#                                                 address  \
# 774   The Hope and Anchor, 207 Upper St, London N1 1...
# 387              16 Highgate High St, London N6 5JG, UK
# 1941  56 Old London Rd, Kingston upon Thames KT2 6QA...
# 515                   92 Bramley Rd, London W10 6UG, UK
# 1375  762 High Rd Leytonstone, Greater, Bushwood, Lo...
# 1661                     177 Mare St, London E8 3RH, UK
# 364   336 Green Lanes, Finsbury Park, London N4 1BY, UK
# 37                     129 City Rd, London EC1V 1JB, UK
# 1796  Gigi's Hoxton, 11 Hoxton Square, London N1 6NU...
# 1794               2-4 Hoxton Square, London N1 6NU, UK
# 482                   74 Hoppers Rd, London N21 3LH, UK
# 1980                  20 Wardour St, London W1D 6QG, UK
# 43                 29-31 Piccadilly, London W1J 0LF, UK
# 556       79 Grosvenor Rd, Pimlico, London SW1V 3LA, UK
# 1145                  1 Clayton Rd, London SE15 5JA, UK
# 541             134-146 Curtain Rd, London EC2A 3AR, UK
# 1780            120-124 Curtain Rd, London EC2A 3SQ, UK
# 1783                                London EC2A 3AT, UK
# 1784               350 -354 Old St, London EC1V 9NQ, UK
# 247                   1 Curtain Rd, London EC2A 3JX, UK
# 1370              79 Nightingale Ln, London E11 2EY, UK
# 1526                 16 Carlisle St, London W1D 3BT, UK
# 1360          Archway 435, Avenue Rd, London E7 0JN, UK
#
#                 station_name event_type
# 774   Highbury and Islington        NaN
# 387                 Highgate        NaN
# 1941                Kingston        NaN
# 515             Latimer Road        NaN
# 1375             Leytonstone        NaN
# 1661           London Fields        NaN
# 364              Manor House        NaN
# 37                Old Street        NaN
# 1796              Old Street        NaN
# 1794              Old Street        NaN
# 482            Palmers Green        NaN
# 1980       Piccadilly Circus        NaN
# 43         Piccadilly Circus        NaN
# 556                  Pimlico        NaN
# 1145     Queens Road Peckham        NaN
# 541   Shoreditch High Street        NaN
# 1780  Shoreditch High Street        NaN
# 1783  Shoreditch High Street        NaN
# 1784  Shoreditch High Street        NaN
# 247   Shoreditch High Street        NaN
# 1370             Snaresbrook        NaN
# 1526    Tottenham Court Road        NaN
# 1360           Wanstead Park        NaN

# %%
import os
import pandas as pd
import numpy as np
directory_path = os.getcwd()
df_rev = pd.read_csv(directory_path + '/review.csv')
# df_rev2 = df_rev.loc[df_rev['review_identity'].isna()]
df_rev['review_identity']=np.where(df_rev['review_identity'].isna(),str(uuid.uuid4()),df_rev['review_identity'])

# df_evnt = pd.read_csv(directory_path + '/event.csv')
# df_evnt2 = df_evnt.loc[(df_evnt['event_type'] == 'comedy')]
# df_rev_evnt = pd.merge(df_rev, df_evnt2, on='pub_identity', how='right')
# df = df_rev_evnt[['pub_identity']]
# df_rev_evnt2 = df_rev_evnt.loc[(df_rev_evnt['entertain'] == '1')|(df_rev_evnt['entertain'] == 1)]

# df_join[['detail_name','event_type']]
# filtered_df = df_join[df_join['event_identity'].isna()]
# filtered_df[['pub_identity','detail_name','address', 'station_name','event_type']].sort_values('station_name')

# df = df_rev_evnt2[['pub_identity']]

              # ,'entertain','comedy','karaoke','event_type','event_detail']]

# %%
df_rev.to_csv(directory_path + '/review.csv', index=False, sep=',', encoding='utf-8')

# %%
# df_rev.to_csv(directory_path + '/review.csv', index=False, sep=',', encoding='utf-8')
# df_evnt.loc[df_evnt['event_detail'] == 'Karaoke', 'event_type'] = 'karaoke'
import numpy as np
df_rev_evnt = pd.merge(df_rev, df_evnt, on='pub_identity', how='left')
df_rev_evnt.shape[0]
# df_rev['karaoke']=np.where(df_rev_evnt['event_type'] == 'karaoke','1','0')
# df_rev.shape[0]
# Out:
# 2283

# %%
import os
import pandas as pd
import numpy as np
directory_path = os.getcwd()
df_eve = pd.read_csv(directory_path + '/events.csv')
# df_eve.shape[0]
# Total: 532
# Quiz: 153
# Live music: 114
# Closed: 121
# other: 144
# df_filtered = df_eve.loc[(df_eve['event_type'] == 'Closed')] 
df_filtered = df_eve[(df_eve['event_type'] != 'Quiz') & (df_eve['event_type'] != 'Live music' ) & (df_eve['event_type'] != 'Closed' )]
df_filtered
# Out:
#                            event_identity  \
# 27   9a91c6c1-3783-4278-a5c6-ec90437cb315
# 28   3b0efa92-4713-4bab-9b25-5837c2b7460f
# 29   b8917737-098c-4d26-bfee-88fcf9b9d17f
# 41   deba1eb1-b6f7-4829-847d-5fa516abd56e
# 42   36957e16-4718-49f4-9df8-9745f2b80aae
# ..                                    ...
# 502  3f6e8c3b-31b4-4451-be0d-21a060fe2a98
# 512  4b6def54-9c08-4a2e-be99-b5e5ec76f5f1
# 514  94ccdd8b-9468-4557-8eb3-e272f6251e9f
# 515  690aacbd-51d4-4270-8e17-5b15f74a00e2
# 517  2ec7d47c-5c21-471e-9021-27e7f4c38135
#
#                              pub_identity  event_day  \
# 27   04738700-75a2-4d5c-864d-de41c81995db     sunday
# 28   04ea139a-05b9-42ee-8bd0-3f3271c750e1     monday
# 29   05493a89-5d8f-407c-b5ca-d269f6d5af55   saturday
# 41   0a0b64ce-badb-49b7-b4e6-2a725d564598    tuesday
# 42   0a0b64ce-badb-49b7-b4e6-2a725d564598     friday
# ..                                    ...        ...
# 502  f74c12e3-3d4d-43c8-89a7-57431146438d     sunday
# 512  fb633682-9d29-47d1-81cd-a1848becebb0   thursday
# 514  fbfe14ab-a48b-424f-b09d-6c1478f0edcb  wednesday
# 515  fbfe14ab-a48b-424f-b09d-6c1478f0edcb   thursday
# 517  ff1be3fe-9942-441e-a9e3-f329d0b65eb2     monday
#
#                             event_time                         event_type
# 27                                 NaN                          live jazz
# 28                               Bingo                              Bingo
# 29                                Noon                             Brunch
# 41                         board games                        board games
# 42                                 DJs                                DJs
# ..                                 ...                                ...
# 502                        Sing-a-long                        Sing-a-long
# 512  Live jazz music last of the month  Live jazz music last of the month
# 514                            Karaoke                            Karaoke
# 515                         Race night                         Race night
# 517                           Quiz 8pm                           Quiz 8pm
#
# [144 rows x 5 columns]

# %%
import os
import csv
import pandas as pd
import numpy as np
directory_path = os.getcwd()
full_file = []
days_of_the_week = ['monday','tuesday','wednesday','thursday','friday','saturday','sunday']
df_events = pd.read_csv(directory_path + '/events.csv')


with open(directory_path + '/details.csv') as csv_file:
    next(csv_file)
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        new_line = []
        # print(row[0])
        df_filtered = df_events.loc[(df_events['pub_identity'] == row[0])]
        # print(df_filtered)
        new_line.append(row[0])
        for day in days_of_the_week:
            # print(day)
            try:
                df_day = df_filtered.loc[(df_filtered['event_day'] == day)]
                var_event = df_day['event_identity'].values[0]
            except IndexError:
                var_event = '0'
            
            # print(df_day['event_identity'].values[0])
            new_line.append(var_event)
        full_file.append(new_line)
        # break
# print(full_file)
# df_evnt3.to_csv(directory_path + '/events.csv', index=False, sep=',', encoding='utf-8')

with open('diary.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(full_file)

# %%
import os
import pandas as pd
import numpy as np
directory_path = os.getcwd()
df_evnt = pd.read_csv(directory_path + '/events.csv')
all = df_evnt.shape[0]

df_evnt2 = df_evnt.loc[(df_evnt['event_time'] == 'TBC') & (df_evnt['event_type'] == 'TBC')]
some = df_evnt2.shape[0]
# df_evnt2.shape[0]
print(all, some)

df_evnt3 = df_evnt.drop(df_evnt[df_evnt['event_type'] == 'TBC'].index)
df_evnt3.shape[0]
# Out:
# 3729 2746
# 983

# %%
import os
import pandas as pd
import numpy as np
directory_path = os.getcwd()
df_full = pd.read_csv(directory_path + '/events_full.csv')
df_full.shape[0]
# Out:
# 8729

# %%
df2.to_csv(directory_path + '/reviews.csv', index=False, sep=',', encoding='utf-8')

# %%
df_copy = pd.read_csv(directory_path + '/reviews_copy.csv')
df_copy.head(2)
rslt_df = df_copy[df_copy[name] == 1]
rslt_df.shape[0]
# Out:
# 343

# %%
df_rev.head(2)
rslt_df_rev = df_rev[df_rev[name] == 1]
rslt_df_rev.shape[0]
# Out:
# 343

# %%
df_backup = pd.read_csv(directory_path + '/backups/reviews.csv')
df_backup.head(2)
rslt_df_bkp = df_backup[df_backup[name] == 1]
rslt_df_bkp.shape[0]
# Out:
# 7

# %%
import uuid
uuid.uuid4()
# Out:
# UUID('1961d8ab-8494-4646-8c77-b6799fc20915')

# %%
t1 = datetime.datetime.now()
print(t1)
# Out:
# 2023-12-26 22:31:31.875725

# %%
import datetime
import time

t1 = datetime.datetime.now()
# t1_day = t1.weekday()
# print(t1_day)
# print(str(t1_day) + ' : ' + t1)
time.sleep(2.5)

t2 = datetime.datetime.now()
# t2_day = t2.weekday()
# print(t2_day)
# print(str(t2_day) + ' : ' + t2)

# _1_day = datetime.timedelta(days=1)
# t3 = datetime.datetime.now() - t1
if ((t2 - t1) > datetime.timedelta(days=1) or t1.weekday() != t2.weekday()):
    print("next day")
else:
    print("same day")


# print('Timestamp: {:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now()))
# print('Timestamp: {:%Y-%b-%d %H:%M:%S}'.format(datetime.datetime.now()))
# print('Date now: %s' % datetime.datetime.now())
# print('Date today: %s' % datetime.date.today())

# today = datetime.date.today()
# print("Today's date is {:%b, %d %Y}".format(today))
# Out:
# same day

# %%
import os
import pandas as pd
import requests
base_photo_url = 'https://maps.googleapis.com/maps/api/place/photo?maxwidth=300&photo_reference='
base_url = 'https://maps.googleapis.com/maps/api/place/details/json?'
key = 'AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20'
fields = 'name,photos'
https://maps.googleapis.com/maps/api/place/photo?maxwidth=300
&photo_reference=

https://maps.googleapis.com/maps/api/place/photo?maxwidth=300&photo_reference=AWU5eFjFsO_BtNvCMQvj-Vg2CDzuns6TZGBnqUKNbWK4pcpRYmqscahEK4sbxuF3EDmJi1FTYAss-Ag561FXRyKmniK-F9I86-YWxbpy_0PEcOGxYv-kpLEDxpgoZWvsCWZKbejM7j1vZygbAEY_5_99PDgtTP0081mbNtWnu4FFiBs4-clI&key=AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20


AWU5eFhElLJ2P1H-eKHJbLNayNjCubz9FmbrcmN2MMfbRsEdSKYyCGX_NaiCYp_tGUnY6pMHPpLDjRf8ofGV2tqg0Xk9xnbhxvrG-s43jLXp-2ngJRA9J5oWe4U1_i2lxy-rUrZrStwQWtrr9dJv3spX6TA8dfCYNrejbGNnNJ_1ljsunVbk
&key=AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20
directory_path = os.getcwd()
df_details = pd.read_csv(directory_path + '/details.csv')
df_photos = pd.read_csv(directory_path + '/photos.csv')
for index, row in df_details.iterrows():
    name = row['detail_name']
    pub_id = row['pub_identity']
    full_url = base_url + "place_id=" + place_id + "&key=" + key + "&fields=" + fields
    # full_photo_url = base_photo_url + photo_id + "&key=" + key 
    # + "&fields=" + fields

    response = requests.get(full_url)
    photo_ids = response.json()['result']['photos']
    total_photo_list = []
    for x in photo_ids:
        new_list = [x['photo_reference'], 'false', pub_id]
        # print(new_list)
        total_photo_list.append(new_list)
        # print(new_photo_list)
    # print(total_photo_list)
    df_new_photo = pd.DataFrame(total_photo_list, columns=['photo_identity', 'photo_deletion', 'pub_identity'])
    # print(df_new_photo)
    df_photos = pd.concat([df_photos, df_new_photo], ignore_index=True)
    df_photos.to_csv(directory_path + '/photos_api.csv', index=False, sep=',', encoding='utf-8')

# %%
base_url = 'https://maps.googleapis.com/maps/api/place/details/json?'
key = 'AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20'
fields = 'name,photos'
place_id = 'ChIJKZfgUMoEdkgRjRIYygsCkSY'
full_url = base_url + "place_id=" + place_id + "&key=" + key + "&fields=" + fields
full_url
# response = requests.get(full_url)
# Out:
# 'https://maps.googleapis.com/maps/api/place/details/json?place_id=ChIJKZfgUMoEdkgRjRIYygsCkSY&key=AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20&fields=name,photos'

# %%
place_id = 'ChIJy2QpfVUDdkgR_ZjHMTwf28A'
base_url = 'https://maps.googleapis.com/maps/api/place/details/json?'
key = 'AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20'
fields = 'address_component'
full_url = base_url + "place_id=" + place_id + "&key=" + key + "&fields=" + fields
response = requests.get(full_url)
print(response.json())

# components_by_type = {};
# for x in response.json()['result']['address_components']:
#     components_by_type[x['types'][0]] = x['short_name']


# print(components_by_type)
# Out:
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '29', 'short_name': '29', 'types': ['street_number']}, {'long_name': 'Watling Street', 'short_name': 'Watling St', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'EC4M 9BR', 'short_name': 'EC4M 9BR', 'types': ['postal_code']}]}, 'status': 'OK'}

# %%
import os
import requests
import pandas as pd
directory_path = os.getcwd()

# df[['extra','place','url','website']]

base_url = 'https://maps.googleapis.com/maps/api/place/details/json?'
key = 'AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20'
# fields = 'name,url,website,editorial_summary'
fields = 'address_component'
df_detail = pd.read_csv(directory_path + '/detail.csv')

for index, row in df_detail.iterrows():

    name = row['detail_name']
    pub_id = row['pub_identity']
    website = row['website']
    url = row['url']
    extra = row['extra']
    place_id = row['place']
    # place_id = 'ChIJta8CEZoddkgRzUPFFO6tYHc'
    full_url = base_url + "place_id=" + place_id + "&key=" + key + "&fields=" + fields

    try:
        response = requests.get(full_url)

        components_by_type = {};
        for x in response.json()['result']['address_components']:
            components_by_type[x['types'][0]] = x['short_name']
        
#         for y in components_by_type:
#             print(components_by_type[y])
        if components_by_type['route'] != 'Greater':
            try:
                new_address = "{} {}, {}".format(components_by_type['street_number'],components_by_type['route'],components_by_type['postal_code'])
            except:
                new_address = "{}, {}, {}".format(components_by_type['premise'],components_by_type['route'],components_by_type['postal_code'])

            # print(str(index) + ' : ' + new_address)
            df_detail.loc[df_detail['pub_identity'] == pub_id, 'address'] = new_address
        else:
            print(response.json())
    except:
        print(response.json())

df_detail.to_csv(directory_path + '/detail.csv', index=False, sep=',', encoding='utf-8')

"""
    print(response.json())
    print('**********')
    print(response.json()['result']['address_components'].length)
    break;
    
    try:
        new_name = response.json()['result']['name']
        if (name != new_name):
            print('name :-')
            print(name + ' | ' + new_name + ' : MISMATCHES')
            df_detail.loc[df_detail['pub_identity'] == pub_id, 'detail_name'] = new_name
            
        try:
            new_website = response.json()['result']['website']
            if (website != new_website):
                print('website :-')
                print(website + ' | ' + new_website + ' : MISMATCHES')
                df_detail.loc[df_detail['pub_identity'] == pub_id, 'website'] = new_website
        except Exception:
            pass
            # print('no website for: ' + new_name)
            # print('current website saved: ' + website)

        try:
            new_url = response.json()['result']['url']
            if (url != new_url):
                print('url :-')
                print(url + ' | ' + new_url + ' : MISMATCHES')
                df_detail.loc[df_detail['pub_identity'] == pub_id, 'url'] = new_url
        except Exception:
            pass
            # print('no url for: ' + new_name)
            # print('current url saved: ' + url)

        try:    
            new_extra = response.json()['result']['editorial_summary']['overview']
            if (extra != new_extra):
                print('extra :-')
                print(extra + ' | ' + new_extra + ' : MISMATCHES')
                df_detail.loc[df_detail['pub_identity'] == pub_id, 'extra'] = new_extra
        except Exception:
            pass
            # print('no summary for: ' + new_name)
            # print('current summary saved: ' + extra)

    except:
        print('Error')
        print('csv name: ' + name)
        print('csv pub id: ' + pub_id)
        print('csv place id: ' + place_id)
        print('response: ')
        print(response.json())
df_detail.to_csv(directory_path + '/detail.csv', index=False, sep=',', encoding='utf-8')

    # break
    
# place_id = 'ChIJy2QpfVUDdkgR_ZjHMTwf28A'
# key = 'AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20'
# fields = 'name,url,website,photos,editorial_summary'
# full_url = base_url + "place_id=" + place_id + "&key=" + key + "&fields=" + fields
# # response = requests.get("https://maps.googleapis.com/maps/api/place/details/json?place_id=ChIJy2QpfVUDdkgR_ZjHMTwf28A&key=AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20")
# response = requests.get(full_url)
# # print(response.json())
# response.json()['result']['name']
# response.json()['result']['url']
# response.json()['result']['website']
# response.json()['result']['editorial_summary']['overview']
# # print(len(response.json()['result']['photos']))

# fruits = response.json()['result']['photos']
# for x in fruits:
#   print(x['photo_reference'])
     
"""
# Out:
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '29', 'short_name': '29', 'types': ['street_number']}, {'long_name': 'Watling Street', 'short_name': 'Watling St', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'EC4M 9BR', 'short_name': 'EC4M 9BR', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '91-92', 'short_name': '91-92', 'types': ['street_number']}, {'long_name': 'Strand', 'short_name': 'Strand', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'WC2R 0DW', 'short_name': 'WC2R 0DW', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '37', 'short_name': '37', 'types': ['street_number']}, {'long_name': 'Cavendish Square', 'short_name': 'Cavendish Square', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'W1G 0PP', 'short_name': 'W1G 0PP', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'error_message': 'The provided Place ID is no longer valid. Please refresh cached Place IDs as per https://developers.google.com/places/web-service/place-id#save-id', 'html_attributions': [], 'status': 'NOT_FOUND'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Cleaver Square', 'short_name': 'Cleaver Square', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SE11 4EA', 'short_name': 'SE11 4EA', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Victoria Embankment', 'short_name': 'Victoria Embankment', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SW1A 2HR', 'short_name': 'SW1A 2HR', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Unit 26', 'short_name': 'Unit 26', 'types': ['subpremise']}, {'long_name': 'Hay’s Galleria', 'short_name': 'Hay’s Galleria', 'types': ['premise']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SE1 2HD', 'short_name': 'SE1 2HD', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '1', 'short_name': '1', 'types': ['street_number']}, {'long_name': 'Bellevue Road', 'short_name': 'Bellevue Rd', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'Upper Tooting', 'short_name': 'Upper Tooting', 'types': ['neighborhood', 'political']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SW17 7EG', 'short_name': 'SW17 7EG', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Brewhouse Lane', 'short_name': 'Brewhouse Ln', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SW15 2JQ', 'short_name': 'SW15 2JQ', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Walham Grove', 'short_name': 'Walham Grove', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SW6 1QJ', 'short_name': 'SW6 1QJ', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '33', 'short_name': '33', 'types': ['street_number']}, {'long_name': 'Bedford Road', 'short_name': 'Bedford Rd', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SW4 7SQ', 'short_name': 'SW4 7SQ', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'House', 'short_name': 'House', 'types': ['premise']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SW8 2LE', 'short_name': 'SW8 2LE', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Albert Embankment', 'short_name': 'Albert Embankment', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SE1 7TY', 'short_name': 'SE1 7TY', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '87', 'short_name': '87', 'types': ['street_number']}, {'long_name': 'Noel Road', 'short_name': 'Noel Rd', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'N1 8HD', 'short_name': 'N1 8HD', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Valette Street', 'short_name': 'Valette St', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'E9 6NU', 'short_name': 'E9 6NU', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Stoneleigh Road', 'short_name': 'Stoneleigh Rd.', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'N17 9JW', 'short_name': 'N17 9JW', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '14', 'short_name': '14', 'types': ['street_number']}, {'long_name': 'South End Road', 'short_name': 'S End Rd', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'NW3 2QE', 'short_name': 'NW3 2QE', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '32', 'short_name': '32', 'types': ['street_number']}, {'long_name': 'Downshire Hill', 'short_name': 'Downshire Hill', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'Hampstead Heath', 'short_name': 'Hampstead Heath', 'types': ['neighborhood', 'political']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'NW3 1NT', 'short_name': 'NW3 1NT', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '50', 'short_name': '50', 'types': ['street_number']}, {'long_name': "England's Lane", 'short_name': "England's Ln", 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'Belsize Park', 'short_name': 'Belsize Park', 'types': ['neighborhood', 'political']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'NW3 4UE', 'short_name': 'NW3 4UE', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '65', 'short_name': '65', 'types': ['street_number']}, {'long_name': 'Gloucester Avenue', 'short_name': 'Gloucester Ave.', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'NW1 8JH', 'short_name': 'NW1 8JH', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '110', 'short_name': '110', 'types': ['street_number']}, {'long_name': 'Battersea Rise', 'short_name': 'Battersea Rise', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SW11 1EJ', 'short_name': 'SW11 1EJ', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '37', 'short_name': '37', 'types': ['street_number']}, {'long_name': 'Marloes Road', 'short_name': 'Marloes Rd', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'W8 6LA', 'short_name': 'W8 6LA', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '1', 'short_name': '1', 'types': ['street_number']}, {'long_name': 'Kensington Court Place', 'short_name': 'Kensington Ct Pl', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'W8 5BJ', 'short_name': 'W8 5BJ', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '30', 'short_name': '30', 'types': ['street_number']}, {'long_name': "Queen's Gate Mews", 'short_name': "Queen's Gate Mews", 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'South Kensington', 'short_name': 'South Kensington', 'types': ['neighborhood', 'political']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SW7 5QL', 'short_name': 'SW7 5QL', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '83', 'short_name': '83', 'types': ['street_number']}, {'long_name': 'Moorgate', 'short_name': 'Moorgate', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'EC2M 6SA', 'short_name': 'EC2M 6SA', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SE1 9SP', 'short_name': 'SE1 9SP', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '83', 'short_name': '83', 'types': ['street_number']}, {'long_name': "Saint Paul's Road", 'short_name': "St Paul's Rd", 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'N1 2LY', 'short_name': 'N1 2LY', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Tileyard Road', 'short_name': 'Tileyard Rd', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'N7 9AH', 'short_name': 'N7 9AH', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Spaniards Road', 'short_name': 'Spaniards Rd', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'NW3 7JJ', 'short_name': 'NW3 7JJ', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '29', 'short_name': '29', 'types': ['street_number']}, {'long_name': 'Penton Street', 'short_name': 'Penton St', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'N1 9PX', 'short_name': 'N1 9PX', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '82', 'short_name': '82', 'types': ['street_number']}, {'long_name': 'Islington High Street', 'short_name': 'Islington High St', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'N1 8EQ', 'short_name': 'N1 8EQ', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': "Saint John's Wood Road", 'short_name': "St John's Wood Rd", 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'NW8 8QP', 'short_name': 'NW8 8QP', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Piccadilly', 'short_name': 'Piccadilly', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'W1J 7BX', 'short_name': 'W1J 7BX', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Brook Street', 'short_name': 'Brook St', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'W1K 4HR', 'short_name': 'W1K 4HR', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Grosvenor Square', 'short_name': 'Grosvenor Sq', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'W1K 6JP', 'short_name': 'W1K 6JP', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Pall Mall', 'short_name': 'Pall Mall', 'types': ['route']}, {'long_name': "St. James's", 'short_name': "St. James's", 'types': ['neighborhood', 'political']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SW1Y 6QY', 'short_name': 'SW1Y 6QY', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '41', 'short_name': '41', 'types': ['street_number']}, {'long_name': 'Romney Street', 'short_name': 'Romney St', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SW1P 3RF', 'short_name': 'SW1P 3RF', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Victoria Embankment', 'short_name': 'Victoria Embankment', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'WC2N 6NU', 'short_name': 'WC2N 6NU', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Strand', 'short_name': 'Strand', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'WC2R 0EZ', 'short_name': 'WC2R 0EZ', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '14', 'short_name': '14', 'types': ['street_number']}, {'long_name': 'New Row', 'short_name': 'New Row', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'WC2N 4LF', 'short_name': 'WC2N 4LF', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '68-70', 'short_name': '68-70', 'types': ['street_number']}, {'long_name': 'Whitfield Street', 'short_name': 'Whitfield St', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'W1T 4EY', 'short_name': 'W1T 4EY', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Museum Gardens', 'short_name': 'Museum Gardens', 'types': ['premise']}, {'long_name': 'Bethnal Green', 'short_name': 'Bethnal Green', 'types': ['neighborhood', 'political']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'E2 9PA', 'short_name': 'E2 9PA', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '135 Bishopsgate', 'short_name': '135 Bishopsgate', 'types': ['premise']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'EC2M 3YD', 'short_name': 'EC2M 3YD', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Wood Street', 'short_name': 'Wood St', 'types': ['route']}, {'long_name': 'Aldermanbury', 'short_name': 'Aldermanbury', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'EC2V 7JQ', 'short_name': 'EC2V 7JQ', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Unit 16a', 'short_name': 'Unit 16a', 'types': ['subpremise']}, {'long_name': 'Rosebery Industrial Park', 'short_name': 'Rosebery Industrial Park', 'types': ['premise']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'N17 9SR', 'short_name': 'N17 9SR', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Ferry Lane', 'short_name': 'Ferry Ln', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'N17 9NG', 'short_name': 'N17 9NG', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Crossrail Place', 'short_name': 'Crossrail Pl', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'E14 5AR', 'short_name': 'E14 5AR', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'The O2', 'short_name': 'The O2', 'types': ['point_of_interest', 'establishment']}, {'long_name': 'Peninsula Square', 'short_name': 'Peninsula Square', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SE10 0DX', 'short_name': 'SE10 0DX', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Park Row', 'short_name': 'Park Row', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SE10 9NW', 'short_name': 'SE10 9NW', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '60', 'short_name': '60', 'types': ['street_number']}, {'long_name': 'Greenwich Church Street', 'short_name': 'Greenwich Church St', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SE10 9BL', 'short_name': 'SE10 9BL', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Blenheim Grove', 'short_name': 'Blenheim Grove', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SE15 4QN', 'short_name': 'SE15 4QN', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'The Terrace', 'short_name': 'The Terrace', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SW13 0NR', 'short_name': 'SW13 0NR', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '7', 'short_name': '7', 'types': ['street_number']}, {'long_name': 'Church Road', 'short_name': 'Church Rd', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SW13 9HE', 'short_name': 'SW13 9HE', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '9', 'short_name': '9', 'types': ['street_number']}, {'long_name': 'Barley Mow Passage', 'short_name': 'Barley Mow Passage', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'Chiswick', 'short_name': 'Chiswick', 'types': ['neighborhood', 'political']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'W4 4PH', 'short_name': 'W4 4PH', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Sweetwater Mooring', 'short_name': 'Sweetwater Mooring', 'types': ['point_of_interest', 'establishment']}, {'long_name': 'White Post Lane', 'short_name': 'White Post Ln', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'E9 5EN', 'short_name': 'E9 5EN', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '47', 'short_name': '47', 'types': ['street_number']}, {'long_name': 'Aldgate High Street', 'short_name': 'Aldgate High St', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'EC3N 1AL', 'short_name': 'EC3N 1AL', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '240', 'short_name': '240', 'types': ['street_number']}, {'long_name': 'Great Portland Street', 'short_name': 'Great Portland St', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'W1W 5QU', 'short_name': 'W1W 5QU', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Piazza Walk', 'short_name': 'Piazza Walk', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'E1 8FU', 'short_name': 'E1 8FU', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Avenue Road', 'short_name': 'Avenue Rd', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'E7 0JN', 'short_name': 'E7 0JN', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Lippitts Hill', 'short_name': 'Lippitts Hill', 'types': ['route']}, {'long_name': 'Waltham Abbey', 'short_name': 'Waltham Abbey', 'types': ['locality', 'political']}, {'long_name': 'Loughton', 'short_name': 'Loughton', 'types': ['postal_town']}, {'long_name': 'Essex', 'short_name': 'Essex', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'IG10 4AL', 'short_name': 'IG10 4AL', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '31', 'short_name': '31', 'types': ['street_number']}, {'long_name': 'High Street', 'short_name': 'High St.', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'E11 2AA', 'short_name': 'E11 2AA', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '762', 'short_name': '762', 'types': ['street_number']}, {'long_name': 'High Road Leytonstone', 'short_name': 'High Rd Leytonstone', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'Bushwood', 'short_name': 'Bushwood', 'types': ['neighborhood', 'political']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'E11 3AW', 'short_name': 'E11 3AW', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Buckhurst Way', 'short_name': 'Buckhurst Way', 'types': ['route']}, {'long_name': 'Buckhurst Hill', 'short_name': 'Buckhurst Hill', 'types': ['postal_town']}, {'long_name': 'Essex', 'short_name': 'Essex', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'IG9 6HY', 'short_name': 'IG9 6HY', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Worship Street', 'short_name': 'Worship St', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'EC2A 2FA', 'short_name': 'EC2A 2FA', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '174', 'short_name': '174', 'types': ['street_number']}, {'long_name': 'Queen Victoria Street', 'short_name': 'Queen Victoria St', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'EC4V 4EG', 'short_name': 'EC4V 4EG', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Stew Lane', 'short_name': 'Stew Ln', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'EC4V 3PT', 'short_name': 'EC4V 3PT', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Cousin Lane', 'short_name': 'Cousin Ln', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'EC4R 3TE', 'short_name': 'EC4R 3TE', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '1', 'short_name': '1', 'types': ['subpremise']}, {'long_name': 'Sky Garden Walk', 'short_name': 'Sky Garden Walk', 'types': ['premise']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'EC3M 8AF', 'short_name': 'EC3M 8AF', 'types': ['postal_code']}]}, 'status': 'OK'}
# ...
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Boland House', 'short_name': 'Boland House', 'types': ['premise']}, {'long_name': 'Guy’s Campus', 'short_name': 'Guy’s Campus', 'types': ['premise']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SE1 9RT', 'short_name': 'SE1 9RT', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Wildcroft Road', 'short_name': 'Wildcroft Rd', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SW15 3NG', 'short_name': 'SW15 3NG', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '31-32', 'short_name': '31-32', 'types': ['street_number']}, {'long_name': 'Dean Street', 'short_name': 'Dean St', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'W1D 3SB', 'short_name': 'W1D 3SB', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Soho Theatre', 'short_name': 'Soho Theatre', 'types': ['point_of_interest', 'establishment']}, {'long_name': 'Dean Street', 'short_name': 'Dean St', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'W1D 3NE', 'short_name': 'W1D 3NE', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '25', 'short_name': '25', 'types': ['street_number']}, {'long_name': 'Greek Street', 'short_name': 'Greek St', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'W1D 5DD', 'short_name': 'W1D 5DD', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '93', 'short_name': '93', 'types': ['street_number']}, {'long_name': 'Charing Cross Road', 'short_name': 'Charing Cross Rd', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'WC2H 0DP', 'short_name': 'WC2H 0DP', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'W1D 3JW', 'short_name': 'W1D 3JW', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Peninsula Square', 'short_name': 'Peninsula Square', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SE10 0DX', 'short_name': 'SE10 0DX', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Jessel Drive', 'short_name': 'Jessel Dr', 'types': ['route']}, {'long_name': 'Loughton', 'short_name': 'Loughton', 'types': ['postal_town']}, {'long_name': 'Essex', 'short_name': 'Essex', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'IG10 2EQ', 'short_name': 'IG10 2EQ', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'The Green', 'short_name': 'The Grn', 'types': ['route']}, {'long_name': 'Green Lane', 'short_name': 'Green Ln', 'types': ['route']}, {'long_name': 'Watford', 'short_name': 'Watford', 'types': ['locality', 'political']}, {'long_name': 'Rickmansworth', 'short_name': 'Rickmansworth', 'types': ['postal_town']}, {'long_name': 'Hertfordshire', 'short_name': 'Hertfordshire', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'WD3 3HN', 'short_name': 'WD3 3HN', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'The Green', 'short_name': 'The Grn', 'types': ['route']}, {'long_name': 'Croxley Green', 'short_name': 'Croxley Green', 'types': ['locality', 'political']}, {'long_name': 'Rickmansworth', 'short_name': 'Rickmansworth', 'types': ['postal_town']}, {'long_name': 'Hertfordshire', 'short_name': 'Hertfordshire', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'WD3 3HX', 'short_name': 'WD3 3HX', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Clapham Common South Side', 'short_name': 'Clapham Common South Side', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SW4 9DE', 'short_name': 'SW4 9DE', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '37', 'short_name': '37', 'types': ['street_number']}, {'long_name': 'Cavendish Square', 'short_name': 'Cavendish Square', 'types': ['route']}, {'long_name': 'Greater', 'short_name': 'Greater', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'W1G 0PP', 'short_name': 'W1G 0PP', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Whittington Way', 'short_name': 'Whittington Way', 'types': ['route']}, {'long_name': 'Pinner', 'short_name': 'Pinner', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'HA5 5JS', 'short_name': 'HA5 5JS', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Coburg Road', 'short_name': 'Coburg Rd', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'N22 6TZ', 'short_name': 'N22 6TZ', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Lower Ham Road', 'short_name': 'Lower Ham Rd', 'types': ['route']}, {'long_name': 'Kingston upon Thames', 'short_name': 'Kingston upon Thames', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'KT2 5AU', 'short_name': 'KT2 5AU', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Grand Parade', 'short_name': 'Grand Parade', 'types': ['route']}, {'long_name': 'Green Lanes', 'short_name': 'Green Lanes', 'types': ['route']}, {'long_name': 'Harringay Ladder', 'short_name': 'Harringay Ladder', 'types': ['neighborhood', 'political']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'N4 1JX', 'short_name': 'N4 1JX', 'types': ['postal_code']}]}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '1', 'short_name': '1', 'types': ['subpremise']}, {'long_name': 'Sky Garden Walk', 'short_name': 'Sky Garden Walk', 'types': ['premise']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'EC3M 8AF', 'short_name': 'EC3M 8AF', 'types': ['postal_code']}]}, 'status': 'OK'}
# '\n    print(response.json())\n    print(\'**********\')\n    print(response.json()[\'result\'][\'address_components\'].length)\n    break;\n    \n    try:\n        new_name = response.json()[\'result\'][\'name\']\n        if (name != new_name):\n            print(\'name :-\')\n            print(name + \' | \' + new_name + \' : MISMATCHES\')\n            df_detail.loc[df_detail[\'pub_identity\'] == pub_id, \'detail_name\'] = new_name\n            \n        try:\n            new_website = response.json()[\'result\'][\'website\']\n            if (website != new_website):\n                print(\'website :-\')\n                print(website + \' | \' + new_website + \' : MISMATCHES\')\n                df_detail.loc[df_detail[\'pub_identity\'] == pub_id, \'website\'] = new_website\n        except Exception:\n            pass\n            # print(\'no website for: \' + new_name)\n            # print(\'current website saved: \' + website)\n\n        try:\n            new_url = response.json()[\'result\'][\'url\']\n            if (url != new_url):\n                print(\'url :-\')\n                print(url + \' | \' + new_url + \' : MISMATCHES\')\n                df_detail.loc[df_detail[\'pub_identity\'] == pub_id, \'url\'] = new_url\n        except Exception:\n            pass\n            # print(\'no url for: \' + new_name)\n            # print(\'current url saved: \' + url)\n\n        try:    \n            new_extra = response.json()[\'result\'][\'editorial_summary\'][\'overview\']\n            if (extra != new_extra):\n                print(\'extra :-\')\n                print(extra + \' | \' + new_extra + \' : MISMATCHES\')\n                df_detail.loc[df_detail[\'pub_identity\'] == pub_id, \'extra\'] = new_extra\n        except Exception:\n            pass\n            # print(\'no summary for: \' + new_name)\n            # print(\'current summary saved: \' + extra)\n\n    except:\n        print(\'Error\')\n        print(\'csv name: \' + name)\n        print(\'csv pub id: \' + pub_id)\n        print(\'csv place id: \' + place_id)\n        print(\'response: \')\n        print(response.json())\ndf_detail.to_csv(directory_path + \'/detail.csv\', index=False, sep=\',\', encoding=\'utf-8\')\n\n    # break\n    \n# place_id = \'ChIJy2QpfVUDdkgR_ZjHMTwf28A\'\n# key = \'AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20\'\n# fields = \'name,url,website,photos,editorial_summary\'\n# full_url = base_url + "place_id=" + place_id + "&key=" + key + "&fields=" + fields\n# # response = requests.get("https://maps.googleapis.com/maps/api/place/details/json?place_id=ChIJy2QpfVUDdkgR_ZjHMTwf28A&key=AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20")\n# response = requests.get(full_url)\n# # print(response.json())\n# response.json()[\'result\'][\'name\']\n# response.json()[\'result\'][\'url\']\n# response.json()[\'result\'][\'website\']\n# response.json()[\'result\'][\'editorial_summary\'][\'overview\']\n# # print(len(response.json()[\'result\'][\'photos\']))\n\n# fruits = response.json()[\'result\'][\'photos\']\n# for x in fruits:\n#   print(x[\'photo_reference\'])\n     \n'

# %%
full_url
# Out:
# 'https://maps.googleapis.com/maps/api/place/details/json?place_id=ChIJta8CEZoddkgRzUPFFO6tYHc&key=AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20&fields=name,url,website,photos,editorial_summary'

# %%
import os
import requests
import pandas as pd
directory_path = os.getcwd()

# df[['extra','place','url','website']]

base_url = 'https://maps.googleapis.com/maps/api/place/details/json?'
key = 'AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20'
fields = 'adr_address,address_component'

place_id = 'ChIJta8CEZoddkgRzUPFFO6tYHc'
full_url = base_url + "place_id=" + place_id + "&key=" + key + "&fields=" + fields

response = requests.get(full_url)
print(response.json())
print('**********')
print(len(response.json()['result']['address_components']))

components_by_type = {};
for x in response.json()['result']['address_components']:
    components_by_type[x['types'][0]] = x['short_name']


address = "{}, {}, {}".format(components_by_type['street_number'],components_by_type['route'],components_by_type['postal_code'])
# Out:
# {'html_attributions': [], 'result': {'address_components': [{'long_name': '297', 'short_name': '297', 'types': ['street_number']}, {'long_name': 'Hoxton Street', 'short_name': 'Hoxton St', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'N1 5JX', 'short_name': 'N1 5JX', 'types': ['postal_code']}], 'adr_address': '<span class="street-address">297 Hoxton Street</span>, <span class="locality">London</span> <span class="postal-code">N1 5JX</span>, <span class="country-name">UK</span>'}, 'status': 'OK'}
# **********
# 7
# {'street_number': '297', 'route': 'Hoxton St', 'postal_town': 'London', 'administrative_area_level_2': 'Greater London', 'administrative_area_level_1': 'England', 'country': 'GB', 'postal_code': 'N1 5JX'}

# %%
import os
import pandas as pd
directory_path = os.getcwd()
df = pd.read_csv(directory_path + '/detail.csv')
df[['extra','place','url','website']]
# Out:
#                                                   extra  \
# 0                                  Women made wine shop
# 1     Pub with a history stretching back to the 17th...
# 2     Rebuilt after being bombed during the Blitz, w...
# 3     Gastropub for Modern British fare and local sp...
# 4     Pub in former coal cellar for the Savoy Hotel,...
# ...                                                 ...
# 1350  Relaxed tavern offering a selection of beers &...
# 1351  Pub with chandeliers and patterned wallpaper, ...
# 1352
# 1353  Visitors sing karaoke & drink cocktails at thi...
# 1354  Pub with autographed rock star hall of fame pi...
#
#                             place  \
# 0     ChIJta8CEZoddkgRzUPFFO6tYHc
# 1     ChIJy2QpfVUDdkgR_ZjHMTwf28A
# 2     ChIJtVNpD8sEdkgRW_kxR_77yN4
# 3     ChIJnx8u7bQEdkgRGm5XKuA0SBQ
# 4     ChIJPyb_JskEdkgRDw4ffzUc8cQ
# ...                           ...
# 1350  ChIJ79XUyTsFdkgRj57LTskQHAo
# 1351  ChIJoaxnTn8DdkgRmUPgKypV5uA
# 1352  ChIJX76OWXgbdkgRE3rwNa-Yokk
# 1353  ChIJO37rxdQEdkgR-6IuXr0d0Uo
# 1354  ChIJd7_CwuMadkgR1iI2gEAlQHs
#
#                                                     url  \
# 0      https://maps.google.com/?cid=8602066526339941325
# 1     https://maps.google.com/?cid=13896735418575460605
# 2     https://maps.google.com/?cid=16053357941296855387
# 3      https://maps.google.com/?cid=1461476216469417498
# 4     https://maps.google.com/?cid=14191154916912729615
# ...                                                 ...
# 1350    https://maps.google.com/?cid=728475696523615887
# 1351  https://maps.google.com/?cid=16205733948752413593
# 1352   https://maps.google.com/?cid=5305971189287516691
# 1353   https://maps.google.com/?cid=5391122928105333499
# 1354   https://maps.google.com/?cid=8881139424133784278
#
#                                                 website
# 0                         https://www.wheresfinley.com/
# 1     https://www.nicholsonspubs.co.uk/restaurants/l...
# 2                        https://www.themarquess.co.uk/
# 3                    https://www.georgeinthestrand.com/
# 4     https://www.nicholsonspubs.co.uk/restaurants/l...
# ...                                                 ...
# 1350                                                NaN
# 1351               https://www.thecamberwellarms.co.uk/
# 1352                                                NaN
# 1353                        https://www.luckyvoice.com/
# 1354                    http://www.thehawleyarms.co.uk/
#
# [1355 rows x 4 columns]

# %%
    # UPDATE DF   
    for detail in list(Detail().__dict__.keys()):
            print(detail)
            print(detail + ' : ' + request.form[detail])
            df_details.loc[df_details['pub_identity'] == pub_id, detail] = request.form[detail]

# %%
    # ADD
    def add_detail_df(self, df_details, df_new):
        print('ADD new detail')
        df_appended = pd.concat([df_details, df_new], ignore_index=True)
        # df_full = pd.merge(df_details, df_new, on='pub_identity')
        return df_appended

# %%
    # UPDATE CSV
    def update_detail_csv(self, df_updated_details):
        print('updating detail csv')
        print(df_updated_details)
        df_updated_details.to_csv(directory_path + '/files/details.csv', index=False, sep=',', encoding='utf-8')
        print('csv updated')
        return df_updated_details
