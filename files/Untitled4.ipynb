# %%
import os
import pandas as pd
import numpy as np
directory_path = os.getcwd()
# df_det = pd.read_csv(directory_path + '/details.csv')
df_rev = pd.read_csv(directory_path + '/reviews.csv')
df_copy = pd.read_csv(directory_path + '/reviews_copy.csv')
# df.shape[0]

# df['pub_identity'].nunique()

# # df = pd.read_csv("dup.csv")
# ids = df["pub_identity"]
# df[ids.isin(ids[ids.duplicated()])].sort_values("pub_identity")

# df_joined = df_det.merge(df, on='pub_identity', how='left', indicator=True)
# df_joined


# df_missing = df_det[~df_det['pub_identity'].isin(df['pub_identity'])]
# df_missing['pub_identity'].tolist()

# df_missing2 = df[~df['pub_identity'].isin(df_det['pub_identity'])]
# df_missing2

# # # for index, row in df.iterrows():
# # #     print(row['c1'], row['c2'])
    
# # # df_miss_id = df_missing2['pub_identity']
# # # df_miss_id.shape[0]
# # # df_missing
# # df_new = df[~df['pub_identity'].isin(df_missing2['pub_identity'])]
# # df_new.shape[0]

# df['cocktail'] =0
# df.head(2)
# df.columns.tolist()
# df2 = df[['review_identity',
#  'review_deletion',
#  'pub_identity',
#  'beer',
#  'brunch',
#  'cocktail',
#  'dart',
#  'entertain',
#  'favourite',
#  'garden',
#  'history',
#  'late',
#  'music',
#  'pool',
#  'quiz',
#  'roast',
#  'sport',
#  'nofeature']]
# df2.head(2)
# df_rev.head(2)
# df_rev['beer'] = '0'
# df_rev['cocktail'] = '0'
# df_rev['outdoor'] = '0'
# df_rev['restaurant'] = '0'
# df_rev['wine'] = '0'
# df_rev.columns.tolist()

# df2 = df_rev[['review_identity',
#  'review_deletion',
#  'pub_identity',
#  'brunch',
#  'dart',
#  'entertain',
#  'favourite',
#  'garden',
#  'history',
#  'late',
#  'music',
#  'pool',
#  'quiz',
#  'roast',
#  'sport',
#  'beer',
#  'cocktail',
#  'outdoor',
#  'restaurant',
#  'wine',
#  'nofeature']]
# df2.head(2)

# %%
import uuid
print(str(uuid.uuid4()))
# Out:
# 463d714c-be3b-4167-a9b7-fe293d9c7e69

# %%
import os
import pandas as pd
import numpy as np
directory_path = os.getcwd()
# df_rev = pd.read_csv(directory_path + '/reviews.csv', dtype={'garden': str, 'roast': str})
# df_dtl = pd.read_csv(directory_path + '/detail.csv')
df_rev = pd.read_csv(directory_path + '/review.csv')
# df_st = pd.read_csv(directory_path + '/station.csv')
df_evnt = pd.read_csv(directory_path + '/event.csv')
df_dtl_rev = pd.merge(df_dtl, df_rev, on='pub_identity', how='left')
df_dr_st = pd.merge(df_dtl_rev, df_st, on='station_identity', how='left')
df_join = pd.merge(df_dr_st, df_evnt, on='pub_identity', how='left')
df_join = df_join.loc[(df_join['music'] == '1')|(df_join['music'] == 1)]
# & (df['column_name'] <= B)]
df_join[['detail_name','event_type']]
# df_filtered.shape[0]
filtered_df = df_join[df_join['event_identity'].isna()]
filtered_df[['pub_identity','detail_name','address', 'station_name','event_type']].sort_values('station_name')
# Out:
#                               pub_identity                     detail_name  \
# 774   0a1f8e69-4020-4dad-8a4a-a3925e7d03ce                   Hope & Anchor
# 387   cdfb2c2e-c05d-4891-9228-1e918c4ae0bc                 The Duke's Head
# 1941  24d297ea-6a37-4901-8324-5cb72605c770  The Fighting Cocks Bar & Venue
# 515   57da201e-7e6e-4fe2-b63c-3f43e3b4a66f                   Pig & Whistle
# 1375  102f5a13-bf8f-4d1d-9bcb-f11636f89aff           O'Neill's Leytonstone
# 1661  a34c0a55-6349-4ea9-9921-f0fba7c448b3                         Helgi's
# 364   1d738594-fab9-441a-ae75-2283218418d7                    The Finsbury
# 37    c7223326-661e-49ed-a0b2-da5bd4758508                        Nightjar
# 1796  6d0cf736-4720-4297-a4a8-ef7d91d5869e                   Gigi’s Hoxton
# 1794  3720c7c3-02f8-476c-8939-e1bbe2e72460                  Colours Hoxton
# 482   0f579ca8-06f4-427a-ab4d-ae685bc3a473                  The Dog & Duck
# ...

# %%
import os
import pandas as pd
import numpy as np
directory_path = os.getcwd()
df_rev = pd.read_csv(directory_path + '/review.csv')
# df_rev2 = df_rev.loc[df_rev['review_identity'].isna()]
df_rev['review_identity']=np.where(df_rev['review_identity'].isna(),str(uuid.uuid4()),df_rev['review_identity'])

# df_evnt = pd.read_csv(directory_path + '/event.csv')
# df_evnt2 = df_evnt.loc[(df_evnt['event_type'] == 'comedy')]
# df_rev_evnt = pd.merge(df_rev, df_evnt2, on='pub_identity', how='right')
# df = df_rev_evnt[['pub_identity']]
# df_rev_evnt2 = df_rev_evnt.loc[(df_rev_evnt['entertain'] == '1')|(df_rev_evnt['entertain'] == 1)]

# df_join[['detail_name','event_type']]
# filtered_df = df_join[df_join['event_identity'].isna()]
# filtered_df[['pub_identity','detail_name','address', 'station_name','event_type']].sort_values('station_name')

# df = df_rev_evnt2[['pub_identity']]

              # ,'entertain','comedy','karaoke','event_type','event_detail']]

# %%
df_rev.to_csv(directory_path + '/review.csv', index=False, sep=',', encoding='utf-8')

# %%
# df_rev.to_csv(directory_path + '/review.csv', index=False, sep=',', encoding='utf-8')
# df_evnt.loc[df_evnt['event_detail'] == 'Karaoke', 'event_type'] = 'karaoke'
import numpy as np
df_rev_evnt = pd.merge(df_rev, df_evnt, on='pub_identity', how='left')
df_rev_evnt.shape[0]
# df_rev['karaoke']=np.where(df_rev_evnt['event_type'] == 'karaoke','1','0')
# df_rev.shape[0]
# Out:
# 2283

# %%
import os
import pandas as pd
import numpy as np
directory_path = os.getcwd()
df_eve = pd.read_csv(directory_path + '/events.csv')
# df_eve.shape[0]
# Total: 532
# Quiz: 153
# Live music: 114
# Closed: 121
# other: 144
# df_filtered = df_eve.loc[(df_eve['event_type'] == 'Closed')] 
df_filtered = df_eve[(df_eve['event_type'] != 'Quiz') & (df_eve['event_type'] != 'Live music' ) & (df_eve['event_type'] != 'Closed' )]
df_filtered
# Out:
#                            event_identity  \
# 27   9a91c6c1-3783-4278-a5c6-ec90437cb315
# 28   3b0efa92-4713-4bab-9b25-5837c2b7460f
# 29   b8917737-098c-4d26-bfee-88fcf9b9d17f
# 41   deba1eb1-b6f7-4829-847d-5fa516abd56e
# 42   36957e16-4718-49f4-9df8-9745f2b80aae
# ..                                    ...
# 502  3f6e8c3b-31b4-4451-be0d-21a060fe2a98
# 512  4b6def54-9c08-4a2e-be99-b5e5ec76f5f1
# 514  94ccdd8b-9468-4557-8eb3-e272f6251e9f
# 515  690aacbd-51d4-4270-8e17-5b15f74a00e2
# 517  2ec7d47c-5c21-471e-9021-27e7f4c38135
#
#                              pub_identity  event_day  \
# 27   04738700-75a2-4d5c-864d-de41c81995db     sunday
# 28   04ea139a-05b9-42ee-8bd0-3f3271c750e1     monday
# 29   05493a89-5d8f-407c-b5ca-d269f6d5af55   saturday
# 41   0a0b64ce-badb-49b7-b4e6-2a725d564598    tuesday
# 42   0a0b64ce-badb-49b7-b4e6-2a725d564598     friday
# ..                                    ...        ...
# 502  f74c12e3-3d4d-43c8-89a7-57431146438d     sunday
# ...

# %%
import os
import csv
import pandas as pd
import numpy as np
directory_path = os.getcwd()
full_file = []
days_of_the_week = ['monday','tuesday','wednesday','thursday','friday','saturday','sunday']
df_events = pd.read_csv(directory_path + '/events.csv')


with open(directory_path + '/details.csv') as csv_file:
    next(csv_file)
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        new_line = []
        # print(row[0])
        df_filtered = df_events.loc[(df_events['pub_identity'] == row[0])]
        # print(df_filtered)
        new_line.append(row[0])
        for day in days_of_the_week:
            # print(day)
            try:
                df_day = df_filtered.loc[(df_filtered['event_day'] == day)]
                var_event = df_day['event_identity'].values[0]
            except IndexError:
                var_event = '0'
            
            # print(df_day['event_identity'].values[0])
            new_line.append(var_event)
        full_file.append(new_line)
        # break
# print(full_file)
# df_evnt3.to_csv(directory_path + '/events.csv', index=False, sep=',', encoding='utf-8')

with open('diary.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(full_file)

# %%
import os
import pandas as pd
import numpy as np
directory_path = os.getcwd()
df_evnt = pd.read_csv(directory_path + '/events.csv')
all = df_evnt.shape[0]

df_evnt2 = df_evnt.loc[(df_evnt['event_time'] == 'TBC') & (df_evnt['event_type'] == 'TBC')]
some = df_evnt2.shape[0]
# df_evnt2.shape[0]
print(all, some)

df_evnt3 = df_evnt.drop(df_evnt[df_evnt['event_type'] == 'TBC'].index)
df_evnt3.shape[0]
# Out:
# 3729 2746
# 983

# %%
import os
import pandas as pd
import numpy as np
directory_path = os.getcwd()
df_full = pd.read_csv(directory_path + '/events_full.csv')
df_full.shape[0]
# Out:
# 8729

# %%
df2.to_csv(directory_path + '/reviews.csv', index=False, sep=',', encoding='utf-8')

# %%
df_copy = pd.read_csv(directory_path + '/reviews_copy.csv')
df_copy.head(2)
rslt_df = df_copy[df_copy[name] == 1]
rslt_df.shape[0]
# Out:
# 343

# %%
df_rev.head(2)
rslt_df_rev = df_rev[df_rev[name] == 1]
rslt_df_rev.shape[0]
# Out:
# 343

# %%
df_backup = pd.read_csv(directory_path + '/backups/reviews.csv')
df_backup.head(2)
rslt_df_bkp = df_backup[df_backup[name] == 1]
rslt_df_bkp.shape[0]
# Out:
# 7

# %%
import uuid
uuid.uuid4()
# Out:
# UUID('1961d8ab-8494-4646-8c77-b6799fc20915')

# %%
t1 = datetime.datetime.now()
print(t1)
# Out:
# 2023-12-26 22:31:31.875725

# %%
import datetime
import time

t1 = datetime.datetime.now()
# t1_day = t1.weekday()
# print(t1_day)
# print(str(t1_day) + ' : ' + t1)
time.sleep(2.5)

t2 = datetime.datetime.now()
# t2_day = t2.weekday()
# print(t2_day)
# print(str(t2_day) + ' : ' + t2)

# _1_day = datetime.timedelta(days=1)
# t3 = datetime.datetime.now() - t1
if ((t2 - t1) > datetime.timedelta(days=1) or t1.weekday() != t2.weekday()):
    print("next day")
else:
    print("same day")


# print('Timestamp: {:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now()))
# print('Timestamp: {:%Y-%b-%d %H:%M:%S}'.format(datetime.datetime.now()))
# print('Date now: %s' % datetime.datetime.now())
# print('Date today: %s' % datetime.date.today())

# today = datetime.date.today()
# print("Today's date is {:%b, %d %Y}".format(today))
# Out:
# same day

# %%
import os
import pandas as pd
import requests
base_photo_url = 'https://maps.googleapis.com/maps/api/place/photo?maxwidth=300&photo_reference='
base_url = 'https://maps.googleapis.com/maps/api/place/details/json?'
key = 'AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20'
fields = 'name,photos'
https://maps.googleapis.com/maps/api/place/photo?maxwidth=300
&photo_reference=

https://maps.googleapis.com/maps/api/place/photo?maxwidth=300&photo_reference=AWU5eFjFsO_BtNvCMQvj-Vg2CDzuns6TZGBnqUKNbWK4pcpRYmqscahEK4sbxuF3EDmJi1FTYAss-Ag561FXRyKmniK-F9I86-YWxbpy_0PEcOGxYv-kpLEDxpgoZWvsCWZKbejM7j1vZygbAEY_5_99PDgtTP0081mbNtWnu4FFiBs4-clI&key=AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20


AWU5eFhElLJ2P1H-eKHJbLNayNjCubz9FmbrcmN2MMfbRsEdSKYyCGX_NaiCYp_tGUnY6pMHPpLDjRf8ofGV2tqg0Xk9xnbhxvrG-s43jLXp-2ngJRA9J5oWe4U1_i2lxy-rUrZrStwQWtrr9dJv3spX6TA8dfCYNrejbGNnNJ_1ljsunVbk
&key=AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20
directory_path = os.getcwd()
df_details = pd.read_csv(directory_path + '/details.csv')
df_photos = pd.read_csv(directory_path + '/photos.csv')
for index, row in df_details.iterrows():
    name = row['detail_name']
    pub_id = row['pub_identity']
    full_url = base_url + "place_id=" + place_id + "&key=" + key + "&fields=" + fields
    # full_photo_url = base_photo_url + photo_id + "&key=" + key 
    # + "&fields=" + fields

    response = requests.get(full_url)
    photo_ids = response.json()['result']['photos']
    total_photo_list = []
    for x in photo_ids:
        new_list = [x['photo_reference'], 'false', pub_id]
        # print(new_list)
        total_photo_list.append(new_list)
        # print(new_photo_list)
    # print(total_photo_list)
    df_new_photo = pd.DataFrame(total_photo_list, columns=['photo_identity', 'photo_deletion', 'pub_identity'])
    # print(df_new_photo)
    df_photos = pd.concat([df_photos, df_new_photo], ignore_index=True)
    df_photos.to_csv(directory_path + '/photos_api.csv', index=False, sep=',', encoding='utf-8')

# %%
base_url = 'https://maps.googleapis.com/maps/api/place/details/json?'
key = 'AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20'
fields = 'name,photos'
place_id = 'ChIJKZfgUMoEdkgRjRIYygsCkSY'
full_url = base_url + "place_id=" + place_id + "&key=" + key + "&fields=" + fields
full_url
# response = requests.get(full_url)
# Out:
# 'https://maps.googleapis.com/maps/api/place/details/json?place_id=ChIJKZfgUMoEdkgRjRIYygsCkSY&key=AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20&fields=name,photos'

# %%
key = 'AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20'
base_url_photo = 'https://maps.googleapis.com/maps/api/place/photo?maxwidth=300&photo_reference='
photo_id = 'AWU5eFiCA83ZAirE1G3P6i2ZqiZJzM1qYEMy71xNRqEJIwy6tGnnHSBP1x_SB802f148a9ADpjZWdKUPU4HSK0HH4N4PPd6fmcaKfT2vBKiBuY7QYzKUS__Tgydea4pFdmaO6dNTLvtZrcxY2vha3_GTWISSovCC6SFPcbS960-ZNgINRgmv'
photo_id2 = 'AWU5eFhESHVBggKCxK5FWh6zm3GSFTpbVR69fne2gMa203UClOiOsyqwgyw25FaqEvFF7LN1OpD9L3Z9gFmw8VRF0VEZFkQ3DURWfx1RIWE_o7_XrGGS-SkHqQ8Su0xVcaJeUBU-tA_qIG0AC_CW8FrECBxdoyxPHV2UvIIZvRPG3Czv_TvM'
photo_id3 = 'AWU5eFhkLXXNuJFEyHS7f0SVMOVfzxXfzCHn7hFhG0Bfi82GlAzEbQKT_a9UaeVUSLYdK3yKVo0HCQ-RYMmZtYd-Wg6JfQWhbDhbn_PjyUOZ6XScig9gzCtAZb8UJ-35ddqwCIEK6qy7MJnmh5IcYcJFZoyVGPAPn8tCOFaEi_9jhFscbJLH'
full_url = base_url_photo + photo_id3 + "&key=" + key
full_url
# Out:
# 'https://maps.googleapis.com/maps/api/place/photo?maxwidth=300&photo_reference=AWU5eFhkLXXNuJFEyHS7f0SVMOVfzxXfzCHn7hFhG0Bfi82GlAzEbQKT_a9UaeVUSLYdK3yKVo0HCQ-RYMmZtYd-Wg6JfQWhbDhbn_PjyUOZ6XScig9gzCtAZb8UJ-35ddqwCIEK6qy7MJnmh5IcYcJFZoyVGPAPn8tCOFaEi_9jhFscbJLH&key=AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20'

# %%
import os
import pandas as pd
import requests
base_url = 'https://maps.googleapis.com/maps/api/place/details/json?'
key = 'AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20'
fields = 'name,url,website,photos,editorial_summary'

directory_path = os.getcwd()
df_details = pd.read_csv(directory_path + '/details.csv')
for index, row in df_details.iterrows():
    name = row['detail_name']
    pub_id = row['pub_identity']
    place_id = row['place']
    full_url = base_url + "place_id=" + place_id + "&key=" + key + "&fields=" + fields

    response = requests.get(full_url)
        
    try:
        new_name = response.json()['result']['name']
    
        try:
            new_website = response.json()['result']['website']
            df_details.loc[df_details['pub_identity'] == pub_id, 'website'] = new_website
        except:
            print('no website for: ' + new_name)

        try:
            new_review_url = response.json()['result']['url']
            df_details.loc[df_details['pub_identity'] == pub_id, 'review_url'] = new_review_url
        except:
            print('no url for: ' + new_name)

        try:    
            new_extra = response.json()['result']['editorial_summary']['overview']
            df_details.loc[df_details['pub_identity'] == pub_id, 'extra'] = new_extra
        except:
            print('no summary for: ' + new_name)

    except:
        print('Error')
        print('csv name: ' + name)
        print('csv pub id: ' + pub_id)
        print('csv place id: ' + place_id)
        print('response: ')
        print(response.json())
# df_details.to_csv(directory_path + '/details_api.csv', index=False, sep=',', encoding='utf-8')

    # break
    
# place_id = 'ChIJy2QpfVUDdkgR_ZjHMTwf28A'
# key = 'AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20'
# fields = 'name,url,website,photos,editorial_summary'
# full_url = base_url + "place_id=" + place_id + "&key=" + key + "&fields=" + fields
# # response = requests.get("https://maps.googleapis.com/maps/api/place/details/json?place_id=ChIJy2QpfVUDdkgR_ZjHMTwf28A&key=AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20")
# response = requests.get(full_url)
# # print(response.json())
# response.json()['result']['name']
# response.json()['result']['url']
# response.json()['result']['website']
# response.json()['result']['editorial_summary']['overview']
# # print(len(response.json()['result']['photos']))

# fruits = response.json()['result']['photos']
# for x in fruits:
#   print(x['photo_reference'])
# Out:
# no summary for: Finley's
# no website for: The Gardeners Arms Loughton
# no summary for: The Gardeners Arms Loughton
# no website for: The Gunners
# no summary for: Lord Raglan E17
# no summary for: Turtle Bay Walthamstow
# no website for: Princess Louise
# Error
# csv name: The Regent
# csv pub id: 55f393ed-9aa5-4bb1-96b1-1b940022e694
# csv place id: ChIJlTC9n8UFdkgR1p8mmsmI20Q
# response:
# {'error_message': 'The provided Place ID is no longer valid. Please refresh cached Place IDs as per https://developers.google.com/places/web-service/place-id#save-id', 'html_attributions': [], 'status': 'NOT_FOUND'}
# no website for: The Fox & Hounds
# no summary for: Walthamstow Trades Hall
# no summary for: The Belleville Brewing Co.
# no summary for: The Kernel Brewery Arch 7 Taproom
# no summary for: The Corner Pin
# no summary for: The Old Fields
# no website for: Prince Albert
# no website for: Nolan's
# no summary for: Nolan's
# no summary for: Mother Kelly's
# ...

# %%
full_url
# Out:
# 'https://maps.googleapis.com/maps/api/place/details/json?place_id=ChIJta8CEZoddkgRzUPFFO6tYHc&key=AIzaSyCbb6tdoROEQuBKLZXybG5cNIB4UTc6A20&fields=name,url,website,photos,editorial_summary'

# %%
    # UPDATE DF   
    for detail in list(Detail().__dict__.keys()):
            print(detail)
            print(detail + ' : ' + request.form[detail])
            df_details.loc[df_details['pub_identity'] == pub_id, detail] = request.form[detail]

# %%
    # ADD
    def add_detail_df(self, df_details, df_new):
        print('ADD new detail')
        df_appended = pd.concat([df_details, df_new], ignore_index=True)
        # df_full = pd.merge(df_details, df_new, on='pub_identity')
        return df_appended

# %%
    # UPDATE CSV
    def update_detail_csv(self, df_updated_details):
        print('updating detail csv')
        print(df_updated_details)
        df_updated_details.to_csv(directory_path + '/files/details.csv', index=False, sep=',', encoding='utf-8')
        print('csv updated')
        return df_updated_details

# %%
import os
import pandas as pd
directory_path = os.getcwd()
df_detail = pd.read_csv(directory_path + '/detail.csv')
# df_detail['shortcut'] = ''

df_detail.loc[df_detail['pub_identity'] == '8d4e6681-dff8-4b38-955a-44fb6e2431cc', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == 'ecb72215-6284-4876-8d89-b5ba30789ab2', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '2bfa0639-9e27-4014-9f23-eaafc2ba7588', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '1b463e1c-9190-4275-a39c-d694eb42d636', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '7092252a-1dbb-435b-a339-aff889c58267', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '8ae5f684-6633-4825-8780-ddc00c5af109', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == 'ee786e13-fde0-4d9c-b344-dd4e02718427', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == 'e620aa52-3217-4d9c-b733-36b8e5fe71d6', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '947d55c3-3f2c-46a8-a4d9-bd553792c5de', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == 'db5e405c-979d-447a-a5b7-62b48df4e576', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '50f4ee06-deac-4049-bbd4-0cd727d4c319', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '3e38be80-48d3-4177-a80d-7b670494e234', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '39b363b6-9622-4c44-b828-fc7fcbe5de54', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '9d30f4df-ff9d-4db8-aea9-de6e01d17466', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == 'f2b74a89-ca18-4500-adf6-80d04d21fc35', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '4e657bd9-9975-4f07-be10-5f1fe5677501', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '74545130-94c7-4049-92bd-86ffd7cab6cb', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '7a6c2b0c-ae9c-4812-a776-cbadb8750566', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '1342830d-e087-49e6-8266-71ea278355b2', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '376cd451-32f0-4895-8f0e-ce61fb413b6d', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '56d385be-abf8-4bf1-9afd-8c57441333c7', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '95386618-20c8-41ed-a71b-34bbd737be08', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '140773b1-5883-46a4-9fc5-6d26b2b28be0', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '565e8b02-df6d-45f9-8e9c-8a37dcebedd8', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '781b0d4c-788a-4bcb-8cec-c4384c566b57', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '97db9cac-552f-4b75-a212-3f93f8345106', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == 'd5518e94-d024-4dec-a5ae-7ce30ef25743', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '7370b248-0ad7-4010-979f-a740c898f0c6', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '9b5c6aa8-437d-4ea5-8464-315a27f9d6a8', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == 'd1b6f9d8-77ff-4a30-9ed2-6c3d698c341b', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '9fb9e451-6e05-4804-9e9c-a41156ba4d6d', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '17ee2a1c-5789-46fb-86a6-6e248f4beba9', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '99261dfa-fd36-4e85-b640-86efcd35aa8a', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == 'dabc295c-96f2-44fc-afe0-7b30338e8714', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == 'ab929c95-2063-420d-832b-2ddb7d7aeac8', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == 'ef34d8b4-86aa-4b8b-bf5e-e00b75b6df86', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '4b7948fb-b05a-4e07-a173-8f26639a86b7', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '180f2d7c-ac08-4db1-88a7-ffb8f4d0029d', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '23e53a90-302e-4637-9f1b-a2da81c7ea65', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '76e885a6-f2ac-458e-aa7d-41e1b97d48d3', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == 'ac2a1ab3-0e65-4d73-8850-e421a10ff8b4', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '225ccf9c-41d4-4a1d-8316-a50397a1776f', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '5a5374a7-d466-45ef-86bc-efe0458af6ea', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '914088d4-d125-437d-b1c0-cadc6839dd60', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '00578cd5-83ea-4e42-941e-347298312015', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '97bb7a16-719a-4cba-97d0-a9ccd9c2ef11', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == '34b0cad9-5087-48df-b177-343227ff694f', 'shortcut'] = 'timeout'
df_detail.loc[df_detail['pub_identity'] == 'f933b4b5-3a06-4015-b23d-ded0d4dd8f70', 'shortcut'] = 'timeout'
df_detail.to_csv(directory_path + '/detail.csv', index=False, sep=',', encoding='utf-8')

# %%
# df_detail = pd.read_csv(directory_path + '/detail.csv')
# df_detail = df_detail.drop('shortcut', axis=1)
# df_detail
df_detail.to_csv(directory_path + '/detail.csv', index=False, sep=',', encoding='utf-8')

# %%
df_rev = pd.read_csv(directory_path + '/review.csv')
df2 = df_rev.loc[df_rev['entertain'] == 1]
df2

df_ent = pd.read_csv(directory_path + '/event.csv')
df3 = df_ent.loc[(df_ent['event_day'] == 'wednesday') & (df_ent['event_type'] == 'entertain')]
df3.sort_values('pub_identity')
# Out:
#                             event_identity  \
# 1241  fdf2dc5b-b719-4d9f-a935-649ebea74961
# 808   eeca6e26-1b3d-4c07-be25-238d1f418834
# 1166  8f65d8b2-78cc-43b5-8be6-ee91e57f6d84
# 649   12e7cd91-d0d0-44dd-ba8d-223bf852e5ad
# 922   19b74786-016b-415b-bd07-ba8806fcc6ce
# 850   b5347a04-bf27-4dec-a701-b6332108ba94
# 1018  9bd382c3-1c0f-4552-9d94-f13aa5456515
# 929   b49b6526-efb3-47c9-af59-c5389e5ceecb
# 116   3398dec7-e399-42f8-88de-b1a516c4d844
# 900   409c5c45-dcc2-4d6b-8cc6-cfc56493bbb8
# 630   30cca449-42d4-489b-9b2d-9b1f234fd8d9
# 145   ae391ebb-8e00-41a1-8f64-5f90fe3706e3
# 1180  7dc2d57b-3044-48ae-9a87-14324176a1af
# 978   904d28ea-8026-412d-8496-26577bf1e59b
# 1260  3cd48f7c-d982-4689-8539-cc6d192a7ff4
# 843   b840c15a-844f-4d4b-aec6-d90078d2c7be
# 943   462e5386-cc5d-41a5-b028-805ccb210341
# 1234  a0c9d4a4-f8c1-445d-bbe3-ec03f0a6b40f
# 820   c5fccec8-9cef-4dfd-a923-977b1e4da482
# 600   2bb2b917-5ff8-4413-a761-213620a8e5dd
# 874   7808b791-ed18-42b4-be9e-b111d3263266
# ...
