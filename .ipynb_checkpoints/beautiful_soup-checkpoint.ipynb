# %%
import requests 
from bs4 import BeautifulSoup 
  
  
# Making a GET request 
# r = requests.get('https://www.geeksforgeeks.org/python-programming-language/') 
r = requests.get('http://www.thepubcrawls.co.uk/home/') 
  
# check status code for response received 
# success code - 200 
# print(r) 
  
# Parsing the HTML 
soup = BeautifulSoup(r.content, 'html.parser')
print(soup)
# left_soup = soup.text
# print(left_soup)
# print(soup.prettify())
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>Home</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta charset="utf-8"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="/static/bootstrap/css/bootstrap.min.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/style.css" rel="stylesheet" type="text/css"/>
# <link href="//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css" rel="stylesheet" type="text/css"/>
# <script src="https://code.jquery.com/jquery-1.12.4.js" type="text/javascript"></script>
# <script src="/static/jquery/js/jquery-3.6.3.min.js" type="text/javascript"></script>
# <script src="https://code.jquery.com/ui/1.12.1/jquery-ui.js" type="text/javascript"></script>
# <script src="/static/bootstrap/js/bootstrap.js" type="text/javascript"></script>
# <script src="/static/bootstrap/js/bootstrap.bundle.min.js" type="text/javascript"></script>
# <script src="/static/javascript/html/go_home.js" type="text/javascript"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/axios/1.2.5/axios.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/popper.js@1.16.1/dist/umd/popper.min.js"></script>
# <link href="/static/jquery/css/jquery.dataTables.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="/static/css/layout.css" rel="stylesheet" type="text/css"/>
# <script src="/static/jquery/js/jquery.dataTables.min.js" type="text/javascript"></script>
# <script src="/static/javascript/crawl/distancing.js" type="text/javascript"></script>
# <script src="/static/javascript/crawl/display.js" type="text/javascript"></script>
# <script src="/static/javascript/crawl/display_none.js" type="text/javascript"></script>
# <script src="/static/javascript/crawl/show_map_home.js" type="text/javascript"></script>
# <script src="/static/javascript/html/click_direction.js" type="text/javascript"></script>
# <script src="/static/javascript/html/click_edit.js" type="text/javascript"></script>
# <script src="/static/javascript/html/click_list.js" type="text/javascript"></script>
# <script src="/static/javascript/html/click_pub.js" type="text/javascript"></script>
# <script src="/static/javascript/html/click_station.js" type="text/javascript"></script>
# <script src="/static/javascript/html/click_station_btn.js" type="text/javascript"></script>
# <script src="/static/javascript/html/create_table.js" type="text/javascript"></script>
# <script src="/static/javascript/html/check_week_home.js" type="text/javascript"></script>
# <script src="/static/javascript/html/check_week_list.js" type="text/javascript"></script>
# <script src="/static/javascript/html/feature_click_pub.js" type="text/javascript"></script>
# <script src="/static/javascript/html/feature_click_home.js" type="text/javascript"></script>
# <script src="/static/javascript/html/feature_click_list.js" type="text/javascript"></script>
# <script src="/static/javascript/html/feature_home.js" type="text/javascript"></script>
# <script src="/static/javascript/html/home_direction_changed.js" type="text/javascript"></script>
# <script src="/static/javascript/html/home_station_changed.js" type="text/javascript"></script>
# <script src="/static/javascript/html/column_filter.js" type="text/javascript"></script>
# <script src="/static/javascript/html/feature_list.js" type="text/javascript"></script>
# <script src="/static/javascript/html/filter_table.js" type="text/javascript"></script>
# <script src="/static/javascript/html/go_pub.js" type="text/javascript"></script>
# <script src="/static/javascript/html/go_add.js" type="text/javascript"></script>
# <script src="/static/javascript/html/go_day.js" type="text/javascript"></script>
# <script src="/static/javascript/html/limit_data.js" type="text/javascript"></script>
# <script src="/static/javascript/html/page_layout.js" type="text/javascript"></script>
# <script src="/static/javascript/html/populate_diary.js" type="text/javascript"></script>
# <script src="/static/javascript/html/populate_form.js" type="text/javascript"></script>
# <script src="/static/javascript/html/populate_pub.js" type="text/javascript"></script>
# <script src="/static/javascript/html/populate_test.js" type="text/javascript"></script>
# <script src="/static/javascript/html/populate_table.js" type="text/javascript"></script>
# <script src="/static/javascript/html/populate_station.js" type="text/javascript"></script>
# <script src="/static/javascript/html/shade_stars.js" type="text/javascript"></script>
# <script src="/static/javascript/html/update_data.js" type="text/javascript"></script>
# <script src="/static/javascript/html/update_icons_list.js" type="text/javascript"></script>
# <script src="/static/javascript/html/update_icons_pub.js" type="text/javascript"></script>
# <script src="/static/javascript/html/update_header.js" type="text/javascript"></script>
# <script src="/static/javascript/html/update_list_station.js" type="text/javascript"></script>
# <script src="/static/javascript/maps/add_map_click.js" type="text/javascript"></script>
# <script src="/static/javascript/maps/add_markers.js" type="text/javascript"></script>
# <script src="/static/javascript/maps/add_markers_2.js" type="text/javascript"></script>
# <script src="/static/javascript/maps/add_markers_3.js" type="text/javascript"></script>
# <script src="/static/javascript/maps/add_marker_bounds.js" type="text/javascript"></script>
# <script src="/static/javascript/maps/calculate_directions_count.js" type="text/javascript"></script>
# <script src="/static/javascript/maps/calculate_stations_count.js" type="text/javascript"></script>
# <script src="/static/javascript/maps/code_address.js" type="text/javascript"></script>
# <script src="/static/javascript/maps/latlng_avg.js" type="text/javascript"></script>
# <script src="/static/javascript/maps/listen_bounds_changed.js" type="text/javascript"></script>
# <script src="/static/javascript/maps/listen_search.js" type="text/javascript"></script>
# <script src="/static/javascript/maps/map_listen_bounds.js" type="text/javascript"></script>
# <script src="/static/javascript/maps/map_load.js" type="text/javascript"></script>
# <script src="/static/javascript/maps/map_visible.js" type="text/javascript"></script>
# <script src="/static/javascript/maps/show_map.js" type="text/javascript"></script>
# <!--<script type="text/javascript" src="/static/javascript/onload/import_variables.js"></script>-->
# <script>
# all_data = []
# alias = {"address": "address", "area_deletion": "Delete", "area_identity": "Id", "area_latitude": "Latitude", "area_longitude": "Longitude", "area_name": "Area", "area_type": "Type", "brunch": "brunch", "category": "Category", "colour": "Colour", "dart": "darts", "detail": "extra info", "direction_deletion": "none", "direction_identity": "Direction ID", "direction_name": "Area", "distance": "distance", "entertain": "fun", "favourite": "best", "friday": "friday", "garden": "garden", "history": "history", "late": "late", "monday": "monday", "music": "music", "parent_identity": "Id", "photo_identity": "Photo Id", "place": "Place", "pool": "pool", "postcode": "none", "pub_deletion": "Delete", "pub_identity": "pub_identity", "pub_latitude": "Latitude", "pub_longitude": "Longitude", "pub_name": "name", "quiz": "quiz", "rank": "rating", "review_deletion": "Review Delete", "review_identity": "Review Id", "roast": "sunday", "saturday": "saturday", "sport": "live", "station_deletion": "none", "station_identity": "Id", "station_latitude": "none", "station_longitude": "none", "station_name": "station", "sunday": "sunday", "thursday": "thursday", "tuesday": "tuesday", "wednesday": "wednesday", "zone": "none"}
# check_list = ["brunch", "dart", "entertain", "favourite", "garden", "history", "late", "music", "pool", "quiz", "roast", "sport"]
# config2 = {"access_id": "AKIAUNBYSFXT5T2V7GHL", "access_key": "x0EZdhPYFbHWq7wjTmwb1usrI5Y7xrOw+5Kb1Tvm", "bucket_name": "s3-git-20221219-pubs", "directory_path": "/app", "env": "prod", "google_key": "AIzaSyAC74SgoLIQfEbtW2sUaYFdxCz6tTsPPbE"}
# date_list = []
# diary_headers = ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"]
# directions_list = []
# dropdown_list = ["category"]
# fields_list = ["pub_identity", "address", "area_identity", "category", "place", "colour", "pub_deletion", "pub_latitude", "pub_longitude", "pub_name", "rank", "station_identity", "detail", "review_identity", "review_deletion", "pub_identity", "brunch", "dart", "entertain", "favourite", "garden", "history", "late", "music", "pool", "quiz", "roast", "sport", "area_identity", "area_deletion", "area_name", "area_type", "area_latitude", "area_longitude", "parent_identity", "photo_identity", "station_identity", "station_deletion", "station_name", "station_latitude", "station_longitude", "zone", "postcode", "direction_identity"]
# form_visible_list = ["address", "pub_name", "rank", "detail", "station_name"]
# headers = ["area_identity", "pub_deletion", "pub_name", "address", "category", "colour", "place", "pub_latitude", "pub_longitude", "rank", "detail", "review_identity", "review_deletion", "brunch", "dart", "entertain", "favourite", "garden", "history", "late", "music", "pool", "quiz", "roast", "sport", "station_identity", "station_deletion", "station_name", "station_latitude", "station_longitude", "zone", "postcode", "direction_identity", "direction_name", "direction_deletion", "pub_identity", "monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday", "distance"]
# icon_list = ["brunch", "dart", "entertain", "favourite", "garden", "history", "late", "music", "pool", "quiz", "roast", "sport"]
# input_list = ["pub_identity", "address", "colour", "pub_name", "detail", "pub_identity", "area_name", "station_name", "direction_identity"]
# required_list = ["address", "category", "pub_latitude", "pub_longitude", "pub_name", "dart", "entertain", "favourite", "garden", "history", "late", "music", "pool", "quiz", "roast", "sport", "area_name", "station_name"]
# slider_list = []
# star_list = ["rank"]
# stations_directions_list = []
# visible = {"address": "false", "area_deletion": "false", "area_identity": "false", "area_latitude": "false", "area_longitude": "false", "area_name": "false", "area_type": "false", "brunch": "false", "category": "false", "colour": "false", "dart": "false", "detail": "false", "direction_deletion": "false", "direction_identity": "false", "direction_name": "false", "entertain": "false", "favourite": "false", "friday": "false", "garden": "false", "history": "false", "late": "false", "monday": "false", "music": "false", "parent_identity": "false", "photo_identity": "false", "place": "false", "pool": "false", "postcode": "false", "pub_deletion": "false", "pub_identity": "false", "pub_latitude": "false", "pub_longitude": "false", "pub_name": "true", "quiz": "false", "rank": "true", "review_deletion": "false", "review_identity": "false", "roast": "false", "saturday": "false", "sport": "false", "station_deletion": "false", "station_identity": "false", "station_latitude": "false", "station_longitude": "false", "station_name": "false", "sunday": "false", "thursday": "false", "tuesday": "false", "wednesday": "false", "zone": "false"}
# </script>
# <script>
# let markersArray = []
#
#
# function onLoad(){
#     console.log('pre-load')
#     var on_line = map_load('AIzaSyAC74SgoLIQfEbtW2sUaYFdxCz6tTsPPbE')
#     console.log('post-load')
#
#     console.log('home - onLoad')
#     console.log('visible')
#     console.log(visible)
#     if ('0' == '0') {
#         page_layout('home')
#     } else {
#         page_layout('edit')
#         click_pub('0')
#     }
#     //add comment
#     display_counter('000202');
# }
#
# function initMap() {
#     console.log("initMap");
#     map = show_map(51.52, -0.127, document.getElementById('mapTEST'))
#     console.log('map - in iniMap')
#     console.log(map)
#     console.log('after map')
#     var markersArray = []
#     if (window.navigator.onLine == true) {
#         document.getElementById('search_map').style.display = 'block'
#         console.log('all_data')
#         console.log(all_data)
#         var new_data = [{pub_name: "placeholder", pub_latitude: 51.52, pub_longitude: -0.127, colour: "#000000"}]
#         console.log('new_data')
#         console.log(new_data)
#         add_markers(map, new_data)
#         var defaultBounds = new google.maps.LatLngBounds(
#           new google.maps.LatLng(51.68, 0.3),      // N, E
#           new google.maps.LatLng(51.40, -0.549));  // S, W
#
#         const input = document.getElementById("search-input-navbar");
#         const searchBox = new google.maps.places.SearchBox(input, {
#             bounds: defaultBounds
#         });
#         listen_search(map, searchBox);
#     }
# }
# </script>
# </head>
# <body onload="onLoad()" style="background-color:#CDCDCD;">
# <div class="container-fluid mx-auto">
# <div class="row header_band" id="header_band"><a class="mx-auto" href="#" onclick="go_home()" style="color:white; text-decoration: none;">The Pub Crawls</a></div>
# <div class="row header_band" style="margin-top: 5px"><a class="mx-auto" style="color:white;">
# <div id="list_header" style="display:none">
# <div id="search_header"></div>
# </div>
# </a></div>
# <!--<div class="row" style="margin: 5px 0 0 0;"></div>-->
# <div class="row" style="margin: 0 0 0 0;">
# <script>console.log('variables.html')</script>
# <input class="hide_x_boxes" id="form_type" type="text" value="home"/>
# <input class="hide_x_boxes" id="auto_exec" type="text" value="off"/>
# <label class="hide_x_boxes" for="x_direction">x_direction</label>
# <input class="hide_x_boxes" id="x_direction" type="text" value="all"/>
# <label class="hide_x_boxes" for="x_station">x_station</label>
# <input class="hide_x_boxes" id="x_station" type="text" value="all"/>
# <label class="hide_x_boxes" for="x_day">x_day</label>
# <input class="hide_x_boxes" id="x_day" type="text" value="all"/>
# <label class="hide_x_boxes" for="load">load</label>
# <input class="hide_x_boxes" id="load" type="text" value=""/>
# <label class="hide_x_boxes" for="x_pub_identity">x_pub_identity</label>
# <input class="hide_x_boxes" id="x_pub_identity" type="text" value=""/>
# <label class="hide_x_boxes" for="x_station_name">x_station_name</label>
# <input class="hide_x_boxes" id="x_station_name" type="text" value=""/>
# <label class="hide_x_boxes" for="x_direction_name">x_direction_name</label>
# <input class="hide_x_boxes" id="x_direction_name" type="text" value=""/>
# <label class="hide_x_boxes" for="x_search">x_search</label>
# <input class="hide_x_boxes" id="x_search" type="text" value=""/>
# <label class="hide_x_boxes" for="x_brunch">x_brunch</label>
# <input class="hide_x_boxes" id="x_brunch" type="text" value="false"/>
# <label class="hide_x_boxes" for="x_dart">x_dart</label>
# <input class="hide_x_boxes" id="x_dart" type="text" value="false"/>
# <label class="hide_x_boxes" for="x_entertain">x_entertain</label>
# <input class="hide_x_boxes" id="x_entertain" type="text" value="false"/>
# <label class="hide_x_boxes" for="x_favourite">x_favourite</label>
# <input class="hide_x_boxes" id="x_favourite" type="text" value="false"/>
# <label class="hide_x_boxes" for="x_garden">x_garden</label>
# <input class="hide_x_boxes" id="x_garden" type="text" value="false"/>
# <label class="hide_x_boxes" for="x_history">x_history</label>
# <input class="hide_x_boxes" id="x_history" type="text" value="false"/>
# <label class="hide_x_boxes" for="x_late">x_late</label>
# <input class="hide_x_boxes" id="x_late" type="text" value="false"/>
# <label class="hide_x_boxes" for="x_music">x_music</label>
# <input class="hide_x_boxes" id="x_music" type="text" value="false"/>
# <label class="hide_x_boxes" for="x_pool">x_pool</label>
# <input class="hide_x_boxes" id="x_pool" type="text" value="false"/>
# <label class="hide_x_boxes" for="x_quiz">x_quiz</label>
# <input class="hide_x_boxes" id="x_quiz" type="text" value="false"/>
# <label class="hide_x_boxes" for="x_roast">x_roast</label>
# <input class="hide_x_boxes" id="x_roast" type="text" value="false"/>
# <label class="hide_x_boxes" for="x_sport">x_sport</label>
# <input class="hide_x_boxes" id="x_sport" type="text" value="false"/>
# </div>
# <div class="row top-buffer" style="margin: 0 0 0 0; display: flex; justify-content: center;">
# <div id="home_page">
# <div class="col-md-12 mx-auto" id="main">
# <div class="row">
# <div class="col-12 center-block text-center" style="padding: 5px 0 0 0;">
# <p style="font-size:8px line-height: 12px">Welcome to the Pub Crawls website.
#         Create your own pub crawl or search for pubs by nearest station or favourite features.</p>
# </div>
# </div>
# <div class="row" style="padding: 10px; border:1px solid #0275d8;">
# <div class="col">
# <div class="row justify-content-center">
# <a href="/pub/areas" style="font-weight: bold; font-size: 14px; color: #000000; text-decoration: none;">Search pubs by area</a>
# </div>
# <div class="row justify-content-center">
# <select class="form-control" id="direction" name="direction" onchange="home_direction_changed();" style="font-size:12px; background-color: #FFFFFF; width:140px;">
# <option value="all">Area</option>
# </select>
# <select class="form-control" id="station" name="station" onchange="home_station_changed();" style="font-size:12px; background-color: #FFFFFF; width:140px;">
# <option value="all">Tube/Train Station</option>
# </select>
# <div id="search_map">
# <input aria-label="Search" id="search-input-navbar" placeholder="Search" style="line-height:30px; font-size:12px; background-color: #FFFFFF; width:200px;" type="search"/>
# </div>
# <a><img class="button_size" onclick="click_list()" src="/static/icons/buttons/arrow.png"/></a>
# </div>
# <script>
# function removeOptions(selectElement) {
#     console.log('remove dropdown options')
#     var i, L = selectElement.options.length - 1;
#     for(i = L; i >= 0; i--) {
#         selectElement.remove(i);
#     }
# }
#
# </script>
# <div class="row" id="pub_week_header">
# <div class="col mx-auto">
# <div class="d-flex justify-content-center" style="font-weight: bold; font-size: 14px;">
#              and/or daily activity
#         </div>
# </div>
# </div>
# <div class="row" id="pub_week">
# <div class="col mx-auto">
# <div class="d-flex justify-content-center">
# <input id="day" style="display: none" type="text" value="all"/>
# <div>
# <div>
# <input id="btn_monday" name="btn_monday" onclick="check_week_home(this.value)" style="display:none" type="checkbox" value="monday"/>
# </div>
# <div>
# <label for="btn_monday" style="margin:0px; padding:0px 3px">
# <img height="40" id="monday_img" src="/static/icons/diary/monday.png" style="opacity: 0.25;" width="40"/>
# </label>
# </div>
# </div>
# <div>
# <div>
# <input id="btn_tuesday" name="btn_tuesday" onclick="check_week_home(this.value)" style="display:none" type="checkbox" value="tuesday"/>
# </div>
# <div>
# <label for="btn_tuesday" style="margin:0px; padding:0px 3px">
# <img height="40" id="tuesday_img" src="/static/icons/diary/tuesday.png" style="opacity: 0.25;" width="40"/>
# </label>
# </div>
# </div>
# <div>
# <div>
# <input id="btn_wednesday" name="btn_wednesday" onclick="check_week_home(this.value)" style="display:none" type="checkbox" value="wednesday"/>
# </div>
# <div>
# <label for="btn_wednesday" style="margin:0px; padding:0px 3px">
# <img height="40" id="wednesday_img" src="/static/icons/diary/wednesday.png" style="opacity: 0.25;" width="40"/>
# </label>
# </div>
# </div>
# <div>
# <div>
# <input id="btn_thursday" name="btn_thursday" onclick="check_week_home(this.value)" style="display:none" type="checkbox" value="thursday"/>
# </div>
# <div>
# <label for="btn_thursday" style="margin:0px; padding:0px 3px">
# <img height="40" id="thursday_img" src="/static/icons/diary/thursday.png" style="opacity: 0.25;" width="40"/>
# </label>
# </div>
# </div>
# <div>
# <div>
# <input id="btn_friday" name="btn_friday" onclick="check_week_home(this.value)" style="display:none" type="checkbox" value="friday"/>
# </div>
# <div>
# <label for="btn_friday" style="margin:0px; padding:0px 3px">
# <img height="40" id="friday_img" src="/static/icons/diary/friday.png" style="opacity: 0.25;" width="40"/>
# </label>
# </div>
# </div>
# <div>
# <div>
# <input id="btn_saturday" name="btn_saturday" onclick="check_week_home(this.value)" style="display:none" type="checkbox" value="saturday"/>
# </div>
# <div>
# <label for="btn_saturday" style="margin:0px; padding:0px 3px">
# <img height="40" id="saturday_img" src="/static/icons/diary/saturday.png" style="opacity: 0.25;" width="40"/>
# </label>
# </div>
# </div>
# <div>
# <div>
# <input id="btn_sunday" name="btn_sunday" onclick="check_week_home(this.value)" style="display:none" type="checkbox" value="sunday"/>
# </div>
# <div>
# <label for="btn_sunday" style="margin:0px; padding:0px 3px">
# <img height="40" id="sunday_img" src="/static/icons/diary/sunday.png" style="opacity: 0.25;" width="40"/>
# </label>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row" id="home_features_header">
# <div class="col-12 center-block text-center">
# <a href="/pub/areas" style="font-weight: bold; font-size: 14px; color: #000000; text-decoration: none;">or by favourite feature</a>
# </div>
# </div>
# <div class="row justify-content-center" id="home_features" style="display:flex; align-items:center;">
# <div id="brunch_col_home" style="text-align:center; padding:5px;">
# <div>
# <input id="brunch_home" name="brunch_home" onclick="feature_click_home('brunch')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="brunch_home" style="margin:0px; padding:0px">
# <img height="25" id="brunch_img_home" src="/static/icons/features/brunch.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="brunch_caption_home" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("brunch_caption_home").innerHTML = "brunch"
#             document.getElementById("brunch_caption_home").style.fontSize = "x-small";
#             document.getElementById("brunch_caption_home").style.fontWeight = "bold";
#         </script>
# <div id="dart_col_home" style="text-align:center; padding:5px;">
# <div>
# <input id="dart_home" name="dart_home" onclick="feature_click_home('dart')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="dart_home" style="margin:0px; padding:0px">
# <img height="25" id="dart_img_home" src="/static/icons/features/dart.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="dart_caption_home" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("dart_caption_home").innerHTML = "darts"
#             document.getElementById("dart_caption_home").style.fontSize = "x-small";
#             document.getElementById("dart_caption_home").style.fontWeight = "bold";
#         </script>
# <div id="entertain_col_home" style="text-align:center; padding:5px;">
# <div>
# <input id="entertain_home" name="entertain_home" onclick="feature_click_home('entertain')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="entertain_home" style="margin:0px; padding:0px">
# <img height="25" id="entertain_img_home" src="/static/icons/features/theatre.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="entertain_caption_home" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("entertain_caption_home").innerHTML = "fun"
#             document.getElementById("entertain_caption_home").style.fontSize = "x-small";
#             document.getElementById("entertain_caption_home").style.fontWeight = "bold";
#         </script>
# <div id="favourite_col_home" style="text-align:center; padding:5px;">
# <div>
# <input id="favourite_home" name="favourite_home" onclick="feature_click_home('favourite')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="favourite_home" style="margin:0px; padding:0px">
# <img height="25" id="favourite_img_home" src="/static/icons/features/favourite.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="favourite_caption_home" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("favourite_caption_home").innerHTML = "best"
#             document.getElementById("favourite_caption_home").style.fontSize = "x-small";
#             document.getElementById("favourite_caption_home").style.fontWeight = "bold";
#         </script>
# <div id="garden_col_home" style="text-align:center; padding:5px;">
# <div>
# <input id="garden_home" name="garden_home" onclick="feature_click_home('garden')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="garden_home" style="margin:0px; padding:0px">
# <img height="25" id="garden_img_home" src="/static/icons/features/garden.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="garden_caption_home" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("garden_caption_home").innerHTML = "garden"
#             document.getElementById("garden_caption_home").style.fontSize = "x-small";
#             document.getElementById("garden_caption_home").style.fontWeight = "bold";
#         </script>
# <div id="history_col_home" style="text-align:center; padding:5px;">
# <div>
# <input id="history_home" name="history_home" onclick="feature_click_home('history')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="history_home" style="margin:0px; padding:0px">
# <img height="25" id="history_img_home" src="/static/icons/features/history.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="history_caption_home" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("history_caption_home").innerHTML = "history"
#             document.getElementById("history_caption_home").style.fontSize = "x-small";
#             document.getElementById("history_caption_home").style.fontWeight = "bold";
#         </script>
# <div id="late_col_home" style="text-align:center; padding:5px;">
# <div>
# <input id="late_home" name="late_home" onclick="feature_click_home('late')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="late_home" style="margin:0px; padding:0px">
# <img height="25" id="late_img_home" src="/static/icons/features/late.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="late_caption_home" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("late_caption_home").innerHTML = "late"
#             document.getElementById("late_caption_home").style.fontSize = "x-small";
#             document.getElementById("late_caption_home").style.fontWeight = "bold";
#         </script>
# <div id="music_col_home" style="text-align:center; padding:5px;">
# <div>
# <input id="music_home" name="music_home" onclick="feature_click_home('music')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="music_home" style="margin:0px; padding:0px">
# <img height="25" id="music_img_home" src="/static/icons/features/music.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="music_caption_home" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("music_caption_home").innerHTML = "music"
#             document.getElementById("music_caption_home").style.fontSize = "x-small";
#             document.getElementById("music_caption_home").style.fontWeight = "bold";
#         </script>
# <div id="pool_col_home" style="text-align:center; padding:5px;">
# <div>
# <input id="pool_home" name="pool_home" onclick="feature_click_home('pool')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="pool_home" style="margin:0px; padding:0px">
# <img height="25" id="pool_img_home" src="/static/icons/features/pool.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="pool_caption_home" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("pool_caption_home").innerHTML = "pool"
#             document.getElementById("pool_caption_home").style.fontSize = "x-small";
#             document.getElementById("pool_caption_home").style.fontWeight = "bold";
#         </script>
# <div id="quiz_col_home" style="text-align:center; padding:5px;">
# <div>
# <input id="quiz_home" name="quiz_home" onclick="feature_click_home('quiz')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="quiz_home" style="margin:0px; padding:0px">
# <img height="25" id="quiz_img_home" src="/static/icons/features/quiz.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="quiz_caption_home" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("quiz_caption_home").innerHTML = "quiz"
#             document.getElementById("quiz_caption_home").style.fontSize = "x-small";
#             document.getElementById("quiz_caption_home").style.fontWeight = "bold";
#         </script>
# <div id="roast_col_home" style="text-align:center; padding:5px;">
# <div>
# <input id="roast_home" name="roast_home" onclick="feature_click_home('roast')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="roast_home" style="margin:0px; padding:0px">
# <img height="25" id="roast_img_home" src="/static/icons/features/chicken.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="roast_caption_home" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("roast_caption_home").innerHTML = "sunday"
#             document.getElementById("roast_caption_home").style.fontSize = "x-small";
#             document.getElementById("roast_caption_home").style.fontWeight = "bold";
#         </script>
# <div id="sport_col_home" style="text-align:center; padding:5px;">
# <div>
# <input id="sport_home" name="sport_home" onclick="feature_click_home('sport')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="sport_home" style="margin:0px; padding:0px">
# <img height="25" id="sport_img_home" src="/static/icons/features/tv.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="sport_caption_home" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("sport_caption_home").innerHTML = "live"
#             document.getElementById("sport_caption_home").style.fontSize = "x-small";
#             document.getElementById("sport_caption_home").style.fontWeight = "bold";
#         </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row top-buffer" style="margin: 0 0 0 0;">
# <div class="col-xs-6 col-sm-6 col-md-6 col-lg-6">
# <div id="list_page1" style="display:none">
# <div class="row justify-content-center">
# <select class="form-control" id="direction_2" name="direction_2" onchange="direction_changed_2();" style="font-size:12px; background-color: #FFFFFF; width:140px;">
# <option value="all">Area</option>
# </select>
# <select class="form-control" id="station_2" name="station_2" onchange="station_changed_2();" style="font-size:12px; background-color: #FFFFFF; width:140px;">
# <option value="all">Tube/Train Station</option>
# </select>
# <input id="search-output-navbar" style="line-height:30px; font-size:12px; background-color: #FFFFFF; width:200px;"/>
# </div>
# <script>
# function removeOptions(selectElement) {
#     console.log('remove dropdown options')
#     var i, L = selectElement.options.length - 1;
#     for(i = L; i >= 0; i--) {
#         selectElement.remove(i);
#     }
# }
# function direction_changed_2() {
#     document.getElementById('search-output-navbar').value = ''
#     console.log('direction_changed_2')
#     var directionSelect = document.getElementById("direction_2");
#     var selectedText = directionSelect.options[directionSelect.selectedIndex].text;
#     value = document.getElementById("direction_2").value
#     //console.log(value)
#     //console.log(selectedText)
#     document.getElementById("station_2").selectedIndex = 0;
#     stations_directions_list = []
#     var select = document.getElementById("station_2");
#     removeOptions(document.getElementById('station_2'));
#     var option = document.createElement("option");
#     option.value = 'all'
#     option.text = "the nearest station"
#     select.add(option);
#     if (value == 'all') {
#         for(var i = 0; i < stations_directions_list.length; i++) {
#             var opt = stations_directions_list[i][1];
#             var el = document.createElement("option");
#             el.textContent = stations_directions_list[i][1];
#             el.value = stations_directions_list[i][0];
#             select.appendChild(el);
#         }
#     } else {
#         filteredArray = stations_directions_list.filter(item => item[2] == value);
#         for(var i = 0; i < filteredArray.length; i++) {
#             var opt = filteredArray[i][1];
#             var el = document.createElement("option");
#             el.textContent = filteredArray[i][1];
#             el.value = filteredArray[i][0];
#             select.appendChild(el);
#         }
#     }
#
#     var e = document.getElementById("direction_2");
#     var value = e.value;
#     var text = e.options[e.selectedIndex].text;
#     //console.log(text)
#     document.getElementById("x_direction").value = value
#     document.getElementById("x_direction_name").value = text
#     click_direction()
# }
# function station_changed_2() {
#     document.getElementById('search-output-navbar').value = ''
#     console.log('station_changed_2')
#     var station_selection = document.getElementById('station_2').value
#     //console.log(document.getElementById('station_2').value)
#     //console.log(document.getElementById('station_2').text)
#     var e = document.getElementById("station_2");
#     var value = e.value;
#     var text = e.options[e.selectedIndex].text;
#     //console.log(text)
#     document.getElementById("x_station").value = value
#     document.getElementById("x_station_name").value = text
#     click_station(value)
#     /*
#     new_direction_array = stations_directions_list.filter(item => item[0] == value)
#     document.getElementById("x_direction").value = new_direction_array[0][2]
#     document.getElementById("x_direction_name").value = new_direction_array[0][3]
#
#
#     var desiredValue = new_direction_array[0][3]
#     var el = document.getElementById("direction_2");
#     for(var i=0; i<el.options.length; i++) {
#       if ( el.options[i].text == desiredValue ) {
#         el.selectedIndex = i;
#         break;
#       }
#     }
#     */
# }
# </script>
# <div class="row justify-content-center" id="list_features" style="display:flex; align-items:center;">
# <div id="brunch_col_list" style="text-align:center; padding:5px;">
# <div>
# <input id="brunch_list" name="brunch_list" onclick="feature_click_list('brunch')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="brunch_list" style="margin:0px; padding:0px">
# <img height="25" id="brunch_img_list" src="/static/icons/features/brunch.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="brunch_caption_list" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("brunch_caption_list").innerHTML = "brunch"
#             document.getElementById("brunch_caption_list").style.fontSize = "x-small";
#             document.getElementById("brunch_caption_list").style.fontWeight = "bold";
#         </script>
# <div id="dart_col_list" style="text-align:center; padding:5px;">
# <div>
# <input id="dart_list" name="dart_list" onclick="feature_click_list('dart')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="dart_list" style="margin:0px; padding:0px">
# <img height="25" id="dart_img_list" src="/static/icons/features/dart.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="dart_caption_list" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("dart_caption_list").innerHTML = "darts"
#             document.getElementById("dart_caption_list").style.fontSize = "x-small";
#             document.getElementById("dart_caption_list").style.fontWeight = "bold";
#         </script>
# <div id="entertain_col_list" style="text-align:center; padding:5px;">
# <div>
# <input id="entertain_list" name="entertain_list" onclick="feature_click_list('entertain')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="entertain_list" style="margin:0px; padding:0px">
# <img height="25" id="entertain_img_list" src="/static/icons/features/theatre.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="entertain_caption_list" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("entertain_caption_list").innerHTML = "fun"
#             document.getElementById("entertain_caption_list").style.fontSize = "x-small";
#             document.getElementById("entertain_caption_list").style.fontWeight = "bold";
#         </script>
# <div id="favourite_col_list" style="text-align:center; padding:5px;">
# <div>
# <input id="favourite_list" name="favourite_list" onclick="feature_click_list('favourite')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="favourite_list" style="margin:0px; padding:0px">
# <img height="25" id="favourite_img_list" src="/static/icons/features/favourite.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="favourite_caption_list" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("favourite_caption_list").innerHTML = "best"
#             document.getElementById("favourite_caption_list").style.fontSize = "x-small";
#             document.getElementById("favourite_caption_list").style.fontWeight = "bold";
#         </script>
# <div id="garden_col_list" style="text-align:center; padding:5px;">
# <div>
# <input id="garden_list" name="garden_list" onclick="feature_click_list('garden')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="garden_list" style="margin:0px; padding:0px">
# <img height="25" id="garden_img_list" src="/static/icons/features/garden.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="garden_caption_list" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("garden_caption_list").innerHTML = "garden"
#             document.getElementById("garden_caption_list").style.fontSize = "x-small";
#             document.getElementById("garden_caption_list").style.fontWeight = "bold";
#         </script>
# <div id="history_col_list" style="text-align:center; padding:5px;">
# <div>
# <input id="history_list" name="history_list" onclick="feature_click_list('history')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="history_list" style="margin:0px; padding:0px">
# <img height="25" id="history_img_list" src="/static/icons/features/history.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="history_caption_list" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("history_caption_list").innerHTML = "history"
#             document.getElementById("history_caption_list").style.fontSize = "x-small";
#             document.getElementById("history_caption_list").style.fontWeight = "bold";
#         </script>
# <div id="late_col_list" style="text-align:center; padding:5px;">
# <div>
# <input id="late_list" name="late_list" onclick="feature_click_list('late')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="late_list" style="margin:0px; padding:0px">
# <img height="25" id="late_img_list" src="/static/icons/features/late.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="late_caption_list" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("late_caption_list").innerHTML = "late"
#             document.getElementById("late_caption_list").style.fontSize = "x-small";
#             document.getElementById("late_caption_list").style.fontWeight = "bold";
#         </script>
# <div id="music_col_list" style="text-align:center; padding:5px;">
# <div>
# <input id="music_list" name="music_list" onclick="feature_click_list('music')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="music_list" style="margin:0px; padding:0px">
# <img height="25" id="music_img_list" src="/static/icons/features/music.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="music_caption_list" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("music_caption_list").innerHTML = "music"
#             document.getElementById("music_caption_list").style.fontSize = "x-small";
#             document.getElementById("music_caption_list").style.fontWeight = "bold";
#         </script>
# <div id="pool_col_list" style="text-align:center; padding:5px;">
# <div>
# <input id="pool_list" name="pool_list" onclick="feature_click_list('pool')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="pool_list" style="margin:0px; padding:0px">
# <img height="25" id="pool_img_list" src="/static/icons/features/pool.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="pool_caption_list" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("pool_caption_list").innerHTML = "pool"
#             document.getElementById("pool_caption_list").style.fontSize = "x-small";
#             document.getElementById("pool_caption_list").style.fontWeight = "bold";
#         </script>
# <div id="quiz_col_list" style="text-align:center; padding:5px;">
# <div>
# <input id="quiz_list" name="quiz_list" onclick="feature_click_list('quiz')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="quiz_list" style="margin:0px; padding:0px">
# <img height="25" id="quiz_img_list" src="/static/icons/features/quiz.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="quiz_caption_list" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("quiz_caption_list").innerHTML = "quiz"
#             document.getElementById("quiz_caption_list").style.fontSize = "x-small";
#             document.getElementById("quiz_caption_list").style.fontWeight = "bold";
#         </script>
# <div id="roast_col_list" style="text-align:center; padding:5px;">
# <div>
# <input id="roast_list" name="roast_list" onclick="feature_click_list('roast')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="roast_list" style="margin:0px; padding:0px">
# <img height="25" id="roast_img_list" src="/static/icons/features/chicken.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="roast_caption_list" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("roast_caption_list").innerHTML = "sunday"
#             document.getElementById("roast_caption_list").style.fontSize = "x-small";
#             document.getElementById("roast_caption_list").style.fontWeight = "bold";
#         </script>
# <div id="sport_col_list" style="text-align:center; padding:5px;">
# <div>
# <input id="sport_list" name="sport_list" onclick="feature_click_list('sport')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="sport_list" style="margin:0px; padding:0px">
# <img height="25" id="sport_img_list" src="/static/icons/features/tv.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="sport_caption_list" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("sport_caption_list").innerHTML = "live"
#             document.getElementById("sport_caption_list").style.fontSize = "x-small";
#             document.getElementById("sport_caption_list").style.fontWeight = "bold";
#         </script>
# </div>
# </div>
# <div id="the_map" style="display:none">
# <div class="col">
# <div class="row">
# <div class="map_height" id="mapTEST"></div>
# </div>
# <!--
#     <div class="row">
#         <div id="search_map">
#             <input id="search-input-navbar" class="form-control mr-sm-2" type="search" placeholder="Search" aria-label="Search">
#          </div>
#     </div>
#     -->
# <div class="row">
# <div class="map_height" id="no_map" style="display:none; border: 1px solid #0275d8">
# <img class="fa-quora" height="100" src="/static/icons/no-map.png"/>
# <p style="padding: 200px; text-align: center;">Too many pubs to show on map</p>
# </div>
# </div>
# <div class="row">
# <div class="map_height" id="no_wifi" style="display:none; border: 1px solid #0275d8">
# <img class="fa-quora" height="100" src="/static/icons/no-wifi.png"/>
# <p style="padding: 200px; text-align: center;">Too internet connect to show map</p>
# </div>
# </div>
# <div class="row">
# <div class="map_height" id="map_areas" style="display:none; border: 1px solid #0275d8">
# <p style="margin: 10px; text-align: center;">North</p>
# <p style="margin: 290px; text-align: center;">South</p>
# <p style="margin: 150px 0px 0px 10px; text-align: center;">West</p>
# <p style="margin: 150px 10px 0px 0px; text-align: center;">East</p>
# <p style="margin: 150px 150px 0px 0px; text-align: center;">Central</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-xs-6 col-sm-6 col-md-6 col-lg-6">
# <div id="list_page2" style="display:none">
# <div>
# <div class="row" id="pub_week">
# <div class="col mx-auto">
# <div class="d-flex justify-content-center">
# <input id="day_2" style="display: none" type="text" value="all"/>
# <div>
# <div>
# <input id="btn_monday_2" name="btn_monday_2" onclick="check_week_list(this.value)" style="display:none" type="checkbox" value="monday"/>
# </div>
# <div>
# <label for="btn_monday_2" style="margin:0px; padding:0px 3px">
# <img height="40" id="monday_img_2" src="/static/icons/diary/monday.png" style="opacity: 0.25;" width="40"/>
# </label>
# </div>
# </div>
# <div>
# <div>
# <input id="btn_tuesday_2" name="btn_tuesday_2" onclick="check_week_list(this.value)" style="display:none" type="checkbox" value="tuesday"/>
# </div>
# <div>
# <label for="btn_tuesday_2" style="margin:0px; padding:0px 3px">
# <img height="40" id="tuesday_img_2" src="/static/icons/diary/tuesday.png" style="opacity: 0.25;" width="40"/>
# </label>
# </div>
# </div>
# <div>
# <div>
# <input id="btn_wednesday_2" name="btn_wednesday_2" onclick="check_week_list(this.value)" style="display:none" type="checkbox" value="wednesday"/>
# </div>
# <div>
# <label for="btn_wednesday_2" style="margin:0px; padding:0px 3px">
# <img height="40" id="wednesday_img_2" src="/static/icons/diary/wednesday.png" style="opacity: 0.25;" width="40"/>
# </label>
# </div>
# </div>
# <div>
# <div>
# <input id="btn_thursday_2" name="btn_thursday_2" onclick="check_week_list(this.value)" style="display:none" type="checkbox" value="thursday"/>
# </div>
# <div>
# <label for="btn_thursday_2" style="margin:0px; padding:0px 3px">
# <img height="40" id="thursday_img_2" src="/static/icons/diary/thursday.png" style="opacity: 0.25;" width="40"/>
# </label>
# </div>
# </div>
# <div>
# <div>
# <input id="btn_friday_2" name="btn_friday_2" onclick="check_week_list(this.value)" style="display:none" type="checkbox" value="friday"/>
# </div>
# <div>
# <label for="btn_friday_2" style="margin:0px; padding:0px 3px">
# <img height="40" id="friday_img_2" src="/static/icons/diary/friday.png" style="opacity: 0.25;" width="40"/>
# </label>
# </div>
# </div>
# <div>
# <div>
# <input id="btn_saturday_2" name="btn_saturday_2" onclick="check_week_list(this.value)" style="display:none" type="checkbox" value="saturday"/>
# </div>
# <div>
# <label for="btn_saturday_2" style="margin:0px; padding:0px 3px">
# <img height="40" id="saturday_img_2" src="/static/icons/diary/saturday.png" style="opacity: 0.25;" width="40"/>
# </label>
# </div>
# </div>
# <div>
# <div>
# <input id="btn_sunday_2" name="btn_sunday_2" onclick="check_week_list(this.value)" style="display:none" type="checkbox" value="sunday"/>
# </div>
# <div>
# <label for="btn_sunday_2" style="margin:0px; padding:0px 3px">
# ...
# </div>
# <div class="col" id="div_wednesday" style="width:250px; text-align:left; visibility:visible; display:block; text-align:left">
# <input class="form-control" id="wednesday" name="wednesday" style="font-size:12px; overflow-y: scroll; resize: none; height: 30px; text-align:left; visibility:visible; display:block; width:250px;" type="textarea"/>
# </div>
# </div>
# <div class="form-group row" id="row_thursday">
# <div class="col" style="text-align:right; width:75px; padding:0px; margin:auto;">
# <label class="col-form-label" for="thursday" style="font-size:12px; width:75px; padding:0px; margin:0px;">thursday</label>
# </div>
# <div class="col" id="div_thursday" style="width:250px; text-align:left; visibility:visible; display:block; text-align:left">
# <input class="form-control" id="thursday" name="thursday" style="font-size:12px; overflow-y: scroll; resize: none; height: 30px; text-align:left; visibility:visible; display:block; width:250px;" type="textarea"/>
# </div>
# </div>
# <div class="form-group row" id="row_friday">
# <div class="col" style="text-align:right; width:75px; padding:0px; margin:auto;">
# <label class="col-form-label" for="friday" style="font-size:12px; width:75px; padding:0px; margin:0px;">friday</label>
# </div>
# <div class="col" id="div_friday" style="width:250px; text-align:left; visibility:visible; display:block; text-align:left">
# <input class="form-control" id="friday" name="friday" style="font-size:12px; overflow-y: scroll; resize: none; height: 30px; text-align:left; visibility:visible; display:block; width:250px;" type="textarea"/>
# </div>
# </div>
# <div class="form-group row" id="row_saturday">
# <div class="col" style="text-align:right; width:75px; padding:0px; margin:auto;">
# <label class="col-form-label" for="saturday" style="font-size:12px; width:75px; padding:0px; margin:0px;">saturday</label>
# </div>
# <div class="col" id="div_saturday" style="width:250px; text-align:left; visibility:visible; display:block; text-align:left">
# <input class="form-control" id="saturday" name="saturday" style="font-size:12px; overflow-y: scroll; resize: none; height: 30px; text-align:left; visibility:visible; display:block; width:250px;" type="textarea"/>
# </div>
# </div>
# <div class="form-group row" id="row_sunday">
# <div class="col" style="text-align:right; width:75px; padding:0px; margin:auto;">
# <label class="col-form-label" for="sunday" style="font-size:12px; width:75px; padding:0px; margin:0px;">sunday</label>
# </div>
# <div class="col" id="div_sunday" style="width:250px; text-align:left; visibility:visible; display:block; text-align:left">
# <input class="form-control" id="sunday" name="sunday" style="font-size:12px; overflow-y: scroll; resize: none; height: 30px; text-align:left; visibility:visible; display:block; width:250px;" type="textarea"/>
# </div>
# </div>
# <div class="row justify-content-center" id="list_features" style="display:flex; align-items:center;">
# <div id="brunch_col" style="text-align:center; padding:5px;">
# <div>
# <input id="brunch" name="brunch" onclick="feature_click_edit('brunch')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="brunch" style="margin:0px; padding:0px">
# <img height="25" id="brunch_img" src="/static/icons/features/brunch.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="brunch_caption" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("brunch_caption").innerHTML = "brunch"
#             document.getElementById("brunch_caption").style.fontSize = "x-small";
#             document.getElementById("brunch_caption").style.fontWeight = "bold";
#         </script>
# <div id="dart_col" style="text-align:center; padding:5px;">
# <div>
# <input id="dart" name="dart" onclick="feature_click_edit('dart')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="dart" style="margin:0px; padding:0px">
# <img height="25" id="dart_img" src="/static/icons/features/dart.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="dart_caption" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("dart_caption").innerHTML = "darts"
#             document.getElementById("dart_caption").style.fontSize = "x-small";
#             document.getElementById("dart_caption").style.fontWeight = "bold";
#         </script>
# <div id="entertain_col" style="text-align:center; padding:5px;">
# <div>
# <input id="entertain" name="entertain" onclick="feature_click_edit('entertain')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="entertain" style="margin:0px; padding:0px">
# <img height="25" id="entertain_img" src="/static/icons/features/theatre.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="entertain_caption" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("entertain_caption").innerHTML = "fun"
#             document.getElementById("entertain_caption").style.fontSize = "x-small";
#             document.getElementById("entertain_caption").style.fontWeight = "bold";
#         </script>
# <div id="favourite_col" style="text-align:center; padding:5px;">
# <div>
# <input id="favourite" name="favourite" onclick="feature_click_edit('favourite')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="favourite" style="margin:0px; padding:0px">
# <img height="25" id="favourite_img" src="/static/icons/features/favourite.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="favourite_caption" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("favourite_caption").innerHTML = "best"
#             document.getElementById("favourite_caption").style.fontSize = "x-small";
#             document.getElementById("favourite_caption").style.fontWeight = "bold";
#         </script>
# <div id="garden_col" style="text-align:center; padding:5px;">
# <div>
# <input id="garden" name="garden" onclick="feature_click_edit('garden')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="garden" style="margin:0px; padding:0px">
# <img height="25" id="garden_img" src="/static/icons/features/garden.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="garden_caption" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("garden_caption").innerHTML = "garden"
#             document.getElementById("garden_caption").style.fontSize = "x-small";
#             document.getElementById("garden_caption").style.fontWeight = "bold";
#         </script>
# <div id="history_col" style="text-align:center; padding:5px;">
# <div>
# <input id="history" name="history" onclick="feature_click_edit('history')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="history" style="margin:0px; padding:0px">
# <img height="25" id="history_img" src="/static/icons/features/history.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="history_caption" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("history_caption").innerHTML = "history"
#             document.getElementById("history_caption").style.fontSize = "x-small";
#             document.getElementById("history_caption").style.fontWeight = "bold";
#         </script>
# <div id="late_col" style="text-align:center; padding:5px;">
# <div>
# <input id="late" name="late" onclick="feature_click_edit('late')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="late" style="margin:0px; padding:0px">
# <img height="25" id="late_img" src="/static/icons/features/late.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="late_caption" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("late_caption").innerHTML = "late"
#             document.getElementById("late_caption").style.fontSize = "x-small";
#             document.getElementById("late_caption").style.fontWeight = "bold";
#         </script>
# <div id="music_col" style="text-align:center; padding:5px;">
# <div>
# <input id="music" name="music" onclick="feature_click_edit('music')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="music" style="margin:0px; padding:0px">
# <img height="25" id="music_img" src="/static/icons/features/music.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="music_caption" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("music_caption").innerHTML = "music"
#             document.getElementById("music_caption").style.fontSize = "x-small";
#             document.getElementById("music_caption").style.fontWeight = "bold";
#         </script>
# <div id="pool_col" style="text-align:center; padding:5px;">
# <div>
# <input id="pool" name="pool" onclick="feature_click_edit('pool')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="pool" style="margin:0px; padding:0px">
# <img height="25" id="pool_img" src="/static/icons/features/pool.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="pool_caption" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("pool_caption").innerHTML = "pool"
#             document.getElementById("pool_caption").style.fontSize = "x-small";
#             document.getElementById("pool_caption").style.fontWeight = "bold";
#         </script>
# <div id="quiz_col" style="text-align:center; padding:5px;">
# <div>
# <input id="quiz" name="quiz" onclick="feature_click_edit('quiz')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="quiz" style="margin:0px; padding:0px">
# <img height="25" id="quiz_img" src="/static/icons/features/quiz.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="quiz_caption" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("quiz_caption").innerHTML = "quiz"
#             document.getElementById("quiz_caption").style.fontSize = "x-small";
#             document.getElementById("quiz_caption").style.fontWeight = "bold";
#         </script>
# <div id="roast_col" style="text-align:center; padding:5px;">
# <div>
# <input id="roast" name="roast" onclick="feature_click_edit('roast')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="roast" style="margin:0px; padding:0px">
# <img height="25" id="roast_img" src="/static/icons/features/chicken.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="roast_caption" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("roast_caption").innerHTML = "sunday"
#             document.getElementById("roast_caption").style.fontSize = "x-small";
#             document.getElementById("roast_caption").style.fontWeight = "bold";
#         </script>
# <div id="sport_col" style="text-align:center; padding:5px;">
# <div>
# <input id="sport" name="sport" onclick="feature_click_edit('sport')" style="display:none" type="checkbox"/>
# </div>
# <div>
# <label for="sport" style="margin:0px; padding:0px">
# <img height="25" id="sport_img" src="/static/icons/features/tv.png" style="opacity: 1;" width="25"/>
# </label>
# </div>
# <div class="caption" id="sport_caption" style="font-size: 8px; padding:0px; margin:0px; opacity:1;"></div>
# </div>
# <script>
#             document.getElementById("sport_caption").innerHTML = "live"
#             document.getElementById("sport_caption").style.fontSize = "x-small";
#             document.getElementById("sport_caption").style.fontWeight = "bold";
#         </script>
# </div>
# </div>
# <button class="btn btn-primary btn-block" id="submit" name="submit" type="submit" value="submit">Submit</button>
# <div class="font-size: 8px; text-align: center" id="submit_message"><i>Click venue on map before submitting</i></div>
# <div><a href="/pub/?pub_id=" id="submit_link">Cancel</a></div>
# <script>
#     elem_submit_btn = document.getElementById('submit')
#     elem_submit_msg = document.getElementById('submit_message')
#     elem_submit_lnk = document.getElementById('submit_link')
#     if (form_type == 'add') {
#         elem_submit_btn.disabled = true
#         elem_submit_lnk.setAttribute("style","color:#d9534f;");
#     } else if (form_type == 'edit') {
#         elem_submit_btn.disabled = false
#         elem_submit_msg.setAttribute("style","display:none;");
#         elem_submit_lnk.setAttribute("style","color:#d9534f;");
#     } else {
#         elem_submit_btn.setAttribute("style","display:none;");
#         elem_submit_msg.setAttribute("style","display:none;");
#         elem_submit_lnk.setAttribute("style","display:none;");
#     }
# </script>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="row top-buffer" style="margin: 0 0 0 0;"></div>
# <div class="row top-buffer" style="margin: 0 0 0 0;">
# <div class="col-md-6 mx-auto">
# <script>
# function display_counter(counter) {
#     document.getElementById("digit_100000").innerHTML = counter.substring(0,1)
#     document.getElementById("digit_10000").innerHTML = counter.substring(1,2)
#     document.getElementById("digit_1000").innerHTML = counter.substring(2,3)
#     document.getElementById("digit_100").innerHTML = counter.substring(3,4)
#     document.getElementById("digit_10").innerHTML = counter.substring(4,5)
#     document.getElementById("digit_1").innerHTML = counter.substring(5,6)
# }
# </script>
# <div class="body counter">
# <div class="span" id="digit_100000"></div>
# <div class="span" id="digit_10000"></div>
# <div class="span" id="digit_1000"></div>
# <div class="span" id="digit_100"></div>
# <div class="span" id="digit_10"></div>
# <div class="span" id="digit_1"></div>
# </div>
# <div class="message">Visits to this Page</div>
# <h3><span id="visits"></span></h3>
# <div class="row justify-content-center top-buffer">
# <!--
#     <div style="text-align: center;">
#         <a href="/test"><img src="/static/icons/footer/test.png" class="button_size"></a>
#         <div class="button_caption">TEST<br>SCRIPT</div>
#     </div>
#
#
#         <div style="text-align: center;">
#             <a href="#"><img src="/static/icons/footer/add1.png" onclick="goAdd('','')" class="button_size"></a>
#             <div class="button_caption">ADD<br>PUB</div>
#         </div>
#
#     -->
# <div class="hide_button" id="edit_button" style="text-align: center;">
# <a href="#"><img class="button_size" onclick="click_edit()" src="/static/icons/footer/pencil.png"/></a>
# <div class="button_caption">EDIT<br/>PUB</div>
# </div>
# <!--
# -->
# <div class="hide_button" id="station_button" style="text-align: center;">
# <a href="#"><img class="button_size" onclick="click_station_btn()" src="/static/icons/footer/underground.png"/></a>
# <div class="button_caption">STATION<br/>AREA</div>
# </div>
# <!--
#         <div style="text-align: center;">
#             <a href="/admin"><img src="/static/icons/footer/admin.png" class="button_size"></a>
#             <div class="button_caption">RUN<br>ADMIN</div>
#         </div>
#
#
#         <div style="text-align: center;">
#             <a href="/pub/crawl"><img src="/static/icons/footer/route.png" class="button_size"></a>
#             <div class="button_caption">PUB<br>CRAWL</div>
#         </div>
#
#     -->
# <div class="hide_button" id="home_button" style="text-align: center;">
# <a href="/home/"><img class="button_size" src="/static/icons/footer/home1.png"/></a>
# <div class="button_caption">RETURN<br/>HOME</div>
# </div>
# </div>
# <div class="row justify-content-center top-buffer">
# <a href="/acknowledgements">Icon and image acknowledges</a>
# </div>
# </div>
# </div>
# </div>
# </body>
# </html>
# <script>
#     document.getElementById("header_band").style = "font-size: 32px; font-weight: bold; font-family:Verdana; color: white; padding: 5px 0 0 0; text-align: center;"
# </script>

# %%
s = soup.find('title')
print(s.text)
# print(soup.title.name)
# Out:
# Home

# %%
import io
with io.open('log1.txt', 'a', encoding='utf8') as logfile:
    logfile.write(s.text)

# %%
import io

with io.open('log.txt', 'a', encoding='utf8') as logfile:
    for tr in soup.find_all('tr')[2:]:
        tds = tr.find_all('td')
        logfile.write(u"%s, %s, %s\n" % (tds[0].text, tds[1].text, tds[2].text))

# %%
with open('file1.html') as file1, open('file2.html') as file2:
    for file1Line, file2Line in zip(file1, file2):
        if file1Line != file2Line:
            print(file1Line.strip('\n'))
            print(file2Line.strip('\n'))
